# %% [markdown]
# <a href="https://colab.research.google.com/github/amit3649/digital_analytics/blob/master/Page_Speed_Insights.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Please save a copy of the script to your drive to use it :)
# If you have any issues feel free to email me ruth.everett@deepcrawl.com or on Twitter @rvtheverett.

# %% [markdown]
# To use run each cell at a time and upload your csv file when prompted. The first two steps are optional for testing the packages are installed, the API call is set up correctly and the results are able to be printed.
#
# **PLEASE NOTE:** As this is using the API  I would recommend just using a small set of URLs at a time, especially if you have a large site. For example, you could use your highest trafficked pages, or pages which generate the most revenue. Alternatively if you use templates it would be great for testing sets of these.

# %% [markdown]
# Step 1: Import required packages

# %%
# Import required packages 
import json
import requests
import pandas as pd
import urllib
import time
from google.colab import files
import io

# %% [markdown]
# **Optional Step:** Running one URL through the API to test

# %%
# Define URL  
url = 'https://www.deepcrawl.com/'

# API request url
result = urllib.request.urlopen('https://www.googleapis.com/pagespeedonline/v5/runPagespeed?url={}/&strategy=mobile'\
                                 .format(url)).read().decode('UTF-8')
print(result)
# Out:
# {
#   "captchaResult": "CAPTCHA_NOT_NEEDED",
#   "kind": "pagespeedonline#result",
#   "id": "https://www.deepcrawl.com/",
#   "loadingExperience": {
#     "id": "https://www.deepcrawl.com/",
#     "metrics": {
#       "FIRST_CONTENTFUL_PAINT_MS": {
#         "percentile": 2246,
#         "distributions": [
#           {
#             "min": 0,
#             "max": 1000,
#             "proportion": 0.322289156626506
#           },
#           {
#             "min": 1000,
#             "max": 3000,
#             "proportion": 0.536144578313253
#           },
#           {
#             "min": 3000,
#             "proportion": 0.14156626506024095
#           }
#         ],
#         "category": "AVERAGE"
#       },
#       "FIRST_INPUT_DELAY_MS": {
#         "percentile": 102,
#         "distributions": [
#           {
#             "min": 0,
#             "max": 100,
#             "proportion": 0.94308943089430908
#           },
#           {
#             "min": 100,
#             "max": 300,
#             "proportion": 0.04878048780487805
#           },
#           {
#             "min": 300,
#             "proportion": 0.008130081300813009
#           }
#         ],
#         "category": "AVERAGE"
#       }
#     },
#     "overall_category": "AVERAGE",
#     "initial_url": "https://www.deepcrawl.com/"
#   },
#   "originLoadingExperience": {
#     "id": "https://www.deepcrawl.com",
#     "metrics": {
#       "FIRST_CONTENTFUL_PAINT_MS": {
#         "percentile": 2814,
#         "distributions": [
#           {
#             "min": 0,
#             "max": 1000,
#             "proportion": 0.23798798798798798
#           },
#           {
#             "min": 1000,
#             "max": 3000,
#             "proportion": 0.539039039039039
#           },
#           {
#             "min": 3000,
#             "proportion": 0.22297297297297303
#           }
#         ],
#         "category": "AVERAGE"
#       },
#       "FIRST_INPUT_DELAY_MS": {
#         "percentile": 234,
#         "distributions": [
#           {
#             "min": 0,
#             "max": 100,
#             "proportion": 0.89015691868758906
#           },
#           {
#             "min": 100,
#             "max": 300,
#             "proportion": 0.094151212553495
#           },
#           {
#             "min": 300,
#             "proportion": 0.015691868758915834
#           }
#         ],
#         "category": "AVERAGE"
#       }
#     },
#     "overall_category": "AVERAGE",
#     "initial_url": "https://www.deepcrawl.com/"
#   },
#   "lighthouseResult": {
#     "requestedUrl": "https://www.deepcrawl.com//",
#     "finalUrl": "https://www.deepcrawl.com/",
#     "lighthouseVersion": "5.6.0",
#     "userAgent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/79.0.3945.120 Safari/537.36",
#     "fetchTime": "2020-03-02T21:06:00.341Z",
#     "environment": {
#       "networkUserAgent": "Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3694.0 Mobile Safari/537.36 Chrome-Lighthouse",
#       "hostUserAgent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/79.0.3945.120 Safari/537.36",
#       "benchmarkIndex": 805
#     },
#     "configSettings": {
#       "emulatedFormFactor": "mobile",
#       "locale": "en-US",
#       "onlyCategories": [
#         "performance"
#       ],
#       "channel": "lr"
#     },
#     "audits": {
#       "critical-request-chains": {
#         "id": "critical-request-chains",
#         "title": "Avoid chaining critical requests",
#         "description": "The Critical Request Chains below show you what resources are loaded with a high priority. Consider reducing the length of chains, reducing the download size of resources, or deferring the download of unnecessary resources to improve page load. [Learn more](https://web.dev/critical-request-chains).",
#         "score": null,
#         "scoreDisplayMode": "informative",
#         "displayValue": "12 chains found",
#         "details": {
#           "type": "criticalrequestchain",
#           "chains": {
#             "B36BF159437B9C77BAC46E278368D96B": {
#               "children": {
#                 "B36BF159437B9C77BAC46E278368D96B:redirect": {
#                   "request": {
#                     "endTime": 196497.458678,
#                     "startTime": 196497.190441,
#                     "transferSize": 17108,
#                     "url": "https://www.deepcrawl.com/",
#                     "responseReceivedTime": 196497.458669
#                   },
#                   "children": {
#                     "22.6": {
#                       "request": {
#                         "transferSize": 2688,
#                         "url": "https://kit.fontawesome.com/98f8bc885f.js",
#                         "responseReceivedTime": 196497.630568,
#                         "endTime": 196497.630571,
#                         "startTime": 196497.4814
#                       },
#                       "children": {
#                         "22.64": {
#                           "request": {
#                             "startTime": 196497.634612,
#                             "transferSize": 13752,
#                             "url": "https://kit-free.fontawesome.com/releases/latest/css/free.min.css",
#                             "responseReceivedTime": 196497.754037,
#                             "endTime": 196497.754038
#                           }
#                         },
#                         "22.63": {
#                           "request": {
#                             "startTime": 196497.634148,
#                             "transferSize": 1331,
#                             "url": "https://kit-free.fontawesome.com/releases/latest/css/free-v4-font-face.min.css",
#                             "responseReceivedTime": 196497.747891,
#                             "endTime": 196497.747894
#                           }
#                         },
#                         "22.62": {
#                           "request": {
#                             "url": "https://kit-free.fontawesome.com/releases/latest/css/free-v4-shims.min.css",
#                             "responseReceivedTime": 196497.750607,
#                             "endTime": 196497.750609,
#                             "startTime": 196497.633835,
#                             "transferSize": 4856
#                           }
#                         }
#                       }
#                     },
#                     "22.146": {
#                       "request": {
#                         "transferSize": 27304,
#                         "url": "https://www.deepcrawl.com/wp-content/themes/deepcrawl/fonts/ProximaNova-Regular.woff2",
#                         "responseReceivedTime": 196497.709969,
#                         "endTime": 196497.70997,
#                         "startTime": 196497.676049
#                       }
#                     },
#                     "22.2": {
#                       "request": {
#                         "url": "https://www.deepcrawl.com/wp-includes/css/dist/block-library/style.min.css?ver=5.2.4",
#                         "responseReceivedTime": 196497.54668300002,
#                         "endTime": 196497.546685,
#                         "startTime": 196497.480115,
#                         "transferSize": 6553
#                       }
#                     },
#                     "22.55": {
#                       "request": {
#                         "endTime": 196497.620709,
#                         "startTime": 196497.602305,
#                         "transferSize": 1443,
#                         "url": "https://www.deepcrawl.com/wp-includes/js/wp-embed.min.js?ver=5.2.4",
#                         "responseReceivedTime": 196497.62070600002
#                       }
#                     },
#                     "22.53": {
#                       "request": {
#                         "transferSize": 24638,
#                         "url": "https://www.deepcrawl.com/wp-content/themes/deepcrawl/build/vendors.js?ver=0.0.1",
#                         "responseReceivedTime": 196497.575089,
#                         "endTime": 196497.575092,
#                         "startTime": 196497.543321
#                       }
#                     },
#                     "22.4": {
#                       "request": {
#                         "transferSize": 40078,
#                         "url": "https://www.deepcrawl.com/wp-includes/js/jquery/jquery.js?ver=1.12.4-wp",
#                         "responseReceivedTime": 196497.547473,
#                         "endTime": 196497.547475,
#                         "startTime": 196497.480627
#                       }
#                     },
#                     "22.3": {
#                       "request": {
#                         "transferSize": 31007,
#                         "url": "https://www.deepcrawl.com/wp-content/themes/deepcrawl/build/styles.min.css?ver=5.2.2.1",
#                         "responseReceivedTime": 196497.516679,
#                         "endTime": 196497.516682,
#                         "startTime": 196497.480295
#                       }
#                     },
#                     "22.148": {
#                       "request": {
#                         "startTime": 196497.675538,
#                         "transferSize": 27043,
#                         "url": "https://www.deepcrawl.com/wp-content/themes/deepcrawl/fonts/ProximaNova-Semibold.woff2",
#                         "responseReceivedTime": 196497.70723200002,
#                         "endTime": 196497.707233
#                       }
#                     },
#                     "22.54": {
#                       "request": {
#                         "transferSize": 5589,
#                         "url": "https://www.deepcrawl.com/wp-content/themes/deepcrawl/build/custom.js?ver=0.0.1",
#                         "responseReceivedTime": 196497.579261,
#                         "endTime": 196497.579265,
#                         "startTime": 196497.557332
#                       }
#                     },
#                     "22.5": {
#                       "request": {
#                         "startTime": 196497.481181,
#                         "transferSize": 4984,
#                         "url": "https://www.deepcrawl.com/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1",
#                         "responseReceivedTime": 196497.538651,
#                         "endTime": 196497.538657
#                       }
#                     }
#                   }
#                 }
#               },
#               "request": {
#                 "url": "https://www.deepcrawl.com//",
#                 "responseReceivedTime": 196497.18963200002,
#                 "endTime": 196497.189979,
#                 "startTime": 196496.641162,
#                 "transferSize": 684
#               }
#             }
#           },
#           "longestChain": {
#             "transferSize": 13752,
#             "duration": 1112.8759999992326,
#             "length": 4
#           }
#         }
#       },
#       "dom-size": {
#         "id": "dom-size",
#         "title": "Avoids an excessive DOM size",
#         "description": "A large DOM will increase memory usage, cause longer [style calculations](https://developers.google.com/web/fundamentals/performance/rendering/reduce-the-scope-and-complexity-of-style-calculations), and produce costly [layout reflows](https://developers.google.com/speed/articles/reflow). [Learn more](https://web.dev/dom-size).",
#         "score": 0.93,
#         "scoreDisplayMode": "numeric",
#         "displayValue": "759 elements",
#         "details": {
#           "headings": [
#             {
#               "itemType": "text",
#               "key": "statistic",
#               "text": "Statistic"
#             },
#             {
#               "key": "element",
#               "itemType": "code",
#               "text": "Element"
#             },
#             {
#               "key": "value",
#               "itemType": "numeric",
#               "text": "Value"
#             }
#           ],
#           "type": "table",
#           "items": [
#             {
#               "value": "759",
#               "statistic": "Total DOM Elements"
#             },
#             {
#               "value": "16",
#               "statistic": "Maximum DOM Depth",
#               "element": {
#                 "type": "code",
#                 "value": "\u003cimg src=\"https://www.deepcrawl.com/wp-content/uploads/2019/02/teal-pie.svg\" class=\"lozad\" alt=\"\" height=\"28\" width=\"28\"\u003e"
#               }
#             },
#             {
#               "statistic": "Maximum Child Elements",
#               "element": {
#                 "type": "code",
#                 "value": "\u003cbody class=\"home page-template-default page page-id-303\"\u003e"
#               },
#               "value": "27"
#             }
#           ]
#         },
#         "numericValue": 759
#       },
#       "uses-rel-preload": {
#         "id": "uses-rel-preload",
#         "title": "Preload key requests",
#         "description": "Consider using `\u003clink rel=preload\u003e` to prioritize fetching resources that are currently requested later in page load. [Learn more](https://web.dev/uses-rel-preload).",
#         "score": 1,
#         "scoreDisplayMode": "numeric",
#         "details": {
#           "overallSavingsMs": 0,
#           "type": "opportunity"
#         },
#         "numericValue": 0
#       },
#       "performance-budget": {
#         "id": "performance-budget",
#         "title": "Performance budget",
#         "description": "Keep the quantity and size of network requests under the targets set by the provided performance budget. [Learn more](https://developers.google.com/web/tools/lighthouse/audits/budgets).",
#         "score": null,
#         "scoreDisplayMode": "notApplicable"
#       },
#       "unminified-javascript": {
#         "id": "unminified-javascript",
#         "title": "Minify JavaScript",
#         "description": "Minifying JavaScript files can reduce payload sizes and script parse time. [Learn more](https://web.dev/unminified-javascript).",
#         "score": 1,
#         "scoreDisplayMode": "numeric",
#         "displayValue": "Potential savings of 2 KB",
#         "details": {
#           "headings": [
#             {
#               "label": "URL",
#               "key": "url",
#               "valueType": "url"
#             },
#             {
#               "valueType": "bytes",
#               "label": "Size",
#               "key": "totalBytes"
#             },
#             {
#               "label": "Potential Savings",
#               "key": "wastedBytes",
#               "valueType": "bytes"
#             }
#           ],
#           "type": "opportunity",
#           "items": [
#             {
#               "url": "https://www.deepcrawl.com/wp-content/themes/deepcrawl/build/custom.js?ver=0.0.1",
#               "totalBytes": 5589,
#               "wastedBytes": 2502,
#               "wastedPercent": 44.773807064656069
#             }
#           ],
#           "overallSavingsBytes": 2502,
#           "overallSavingsMs": 0
#         },
#         "numericValue": 0
#       },
#       "redirects": {
#         "id": "redirects",
#         "title": "Avoid multiple page redirects",
#         "description": "Redirects introduce additional delays before the page can be loaded. [Learn more](https://web.dev/redirects).",
#         "score": 1,
#         "scoreDisplayMode": "numeric",
#         "displayValue": "Potential savings of 780 ms",
#         "details": {
#           "overallSavingsMs": 780,
#           "headings": [
#             {
#               "key": "url",
#               "valueType": "url",
#               "label": "URL"
#             },
#             {
#               "key": "wastedMs",
#               "valueType": "timespanMs",
#               "label": "Time Spent"
#             }
#           ],
#           "items": [
#             {
#               "wastedMs": 0,
#               "url": "(Initial: https://www.deepcrawl.com//)"
#             },
#             {
#               "wastedMs": 780,
#               "url": "https://www.deepcrawl.com/"
#             }
#           ],
#           "type": "opportunity"
#         },
#         "numericValue": 780
#       },
#       "user-timings": {
#         "id": "user-timings",
#         "title": "User Timing marks and measures",
#         "description": "Consider instrumenting your app with the User Timing API to measure your app's real-world performance during key user experiences. [Learn more](https://web.dev/user-timings).",
#         "score": null,
#         "scoreDisplayMode": "notApplicable",
#         "details": {
#           "type": "table"
#         }
#       },
#       "first-meaningful-paint": {
#         "id": "first-meaningful-paint",
#         "title": "First Meaningful Paint",
#         "description": "First Meaningful Paint measures when the primary content of a page is visible. [Learn more](https://web.dev/first-meaningful-paint).",
#         "score": 0.62,
#         "scoreDisplayMode": "numeric",
#         "displayValue": "3.5 s",
#         "numericValue": 3514
#       },
#       "resource-summary": {
#         "id": "resource-summary",
#         "title": "Keep request counts low and transfer sizes small",
#         "description": "To set budgets for the quantity and size of page resources, add a budget.json file. [Learn more](https://developers.google.com/web/tools/lighthouse/audits/budgets).",
#         "score": null,
#         "scoreDisplayMode": "informative",
#         "displayValue": "112 requests • 1,106 KB",
#         "details": {
#           "headings": [
#             {
#               "key": "label",
#               "itemType": "text",
#               "text": "Resource Type"
#             },
#             {
#               "text": "Requests",
#               "key": "requestCount",
#               "itemType": "numeric"
#             },
#             {
#               "key": "size",
#               "itemType": "bytes",
#               "text": "Transfer Size"
#             }
#           ],
#           "type": "table",
#           "items": [
#             {
#               "label": "Total",
#               "size": 1132622,
#               "requestCount": 112,
#               "resourceType": "total"
#             },
#             {
#               "resourceType": "image",
#               "label": "Image",
#               "size": 520552,
#               "requestCount": 67
#             },
#             {
#               "label": "Script",
#               "size": 473637,
#               "requestCount": 25,
#               "resourceType": "script"
#             },
#             {
#               "label": "Stylesheet",
#               "size": 57499,
#               "requestCount": 5,
#               "resourceType": "stylesheet"
#             },
#             {
#               "resourceType": "font",
#               "label": "Font",
#               "size": 54347,
#               "requestCount": 2
#             },
#             {
#               "requestCount": 2,
#               "resourceType": "document",
#               "label": "Document",
#               "size": 18461
#             },
#             {
#               "resourceType": "other",
#               "label": "Other",
#               "size": 8126,
#               "requestCount": 11
#             },
#             {
#               "resourceType": "media",
#               "label": "Media",
#               "size": 0,
#               "requestCount": 0
#             },
#             {
#               "resourceType": "third-party",
#               "label": "Third-party",
#               "size": 422409,
#               "requestCount": 37
#             }
#           ]
#         }
#       },
#       "final-screenshot": {
#         "id": "final-screenshot",
#         "title": "Final Screenshot",
#         "description": "The last screenshot captured of the pageload.",
#         "score": null,
#         "scoreDisplayMode": "informative",
#         "details": {
#           "timestamp": 196498406416,
#           "data": "data:image/jpeg;base64,...",
#           "type": "screenshot",
#           "timing": 1766
#         }
#       },
#       "efficient-animated-content": {
#         "id": "efficient-animated-content",
#         "title": "Use video formats for animated content",
#         "description": "Large GIFs are inefficient for delivering animated content. Consider using MPEG4/WebM videos for animations and PNG/WebP for static images instead of GIF to save network bytes. [Learn more](https://web.dev/efficient-animated-content)",
#         "score": 1,
#         "scoreDisplayMode": "numeric",
#         "details": {
#           "type": "opportunity",
#           "overallSavingsBytes": 0,
#           "overallSavingsMs": 0
#         },
#         "numericValue": 0
#       },
#       "metrics": {
#         "id": "metrics",
#         "title": "Metrics",
#         "description": "Collects all available metrics.",
#         "score": null,
#         "scoreDisplayMode": "informative",
#         "details": {
#           "type": "debugdata",
#           "items": [
#             {
#               "observedLargestContentfulPaintTs": 196498405253,
#               "observedFirstVisualChange": 1233,
#               "observedLoadTs": 196499380073,
#               "firstMeaningfulPaint": 3514,
#               "observedFirstMeaningfulPaint": 1765,
#               "observedTraceEnd": 4094,
#               "observedTraceEndTs": 196500733969,
#               "firstCPUIdle": 7534,
#               "observedFirstMeaningfulPaintTs": 196498405253,
#               "observedDomContentLoaded": 1524,
#               "interactive": 7909,
#               "observedFirstVisualChangeTs": 196497873097,
#               "observedNavigationStart": 0,
#               "observedFirstContentfulPaintTs": 196497875837,
#               "observedLastVisualChangeTs": 196498406097,
#               "observedLoad": 2740,
#               "observedLargestContentfulPaint": 1765,
#               "observedDomContentLoadedTs": 196498164092,
#               "observedSpeedIndex": 1606,
#               "estimatedInputLatency": 121,
#               "totalBlockingTime": 1030,
#               "observedFirstPaint": 1236,
#               "observedLastVisualChange": 1766,
#               "firstContentfulPaint": 3094,
#               "observedFirstPaintTs": 196497875837,
#               "speedIndex": 5102,
#               "observedSpeedIndexTs": 196498246422,
#               "observedFirstContentfulPaint": 1236,
#               "observedNavigationStartTs": 196496640097
#             },
#             {
#               "lcpInvalidated": false
#             }
#           ]
#         },
#         "numericValue": 7909
#       },
#       "time-to-first-byte": {
#         "id": "time-to-first-byte",
#         "title": "Server response times are low (TTFB)",
#         "description": "Time To First Byte identifies the time at which your server sends a response. [Learn more](https://web.dev/time-to-first-byte).",
#         "score": 1,
#         "scoreDisplayMode": "binary",
#         "displayValue": "Root document took 270 ms",
#         "details": {
#           "overallSavingsMs": -330.772,
#           "type": "opportunity"
#         },
#         "numericValue": 269.228
#       },
#       "render-blocking-resources": {
#         "id": "render-blocking-resources",
#         "title": "Eliminate render-blocking resources",
#         "description": "Resources are blocking the first paint of your page. Consider delivering critical JS/CSS inline and deferring all non-critical JS/styles. [Learn more](https://web.dev/render-blocking-resources).",
#         "score": 0.43,
#         "scoreDisplayMode": "numeric",
#         "displayValue": "Potential savings of 1,320 ms",
#         "details": {
#           "overallSavingsMs": 1320,
#           "headings": [
#             {
#               "key": "url",
#               "valueType": "url",
#               "label": "URL"
#             },
#             {
#               "valueType": "bytes",
#               "label": "Size",
#               "key": "totalBytes"
#             },
#             {
#               "valueType": "timespanMs",
#               "label": "Potential Savings",
#               "key": "wastedMs"
#             }
#           ],
#           "type": "opportunity",
#           "items": [
#             {
#               "url": "https://www.deepcrawl.com/wp-includes/css/dist/block-library/style.min.css?ver=5.2.4",
#               "totalBytes": 6553,
#               "wastedMs": 330
#             },
#             {
#               "totalBytes": 31007,
#               "wastedMs": 1230,
#               "url": "https://www.deepcrawl.com/wp-content/themes/deepcrawl/build/styles.min.css?ver=5.2.2.1"
#             },
#             {
#               "wastedMs": 1530,
#               "url": "https://www.deepcrawl.com/wp-includes/js/jquery/jquery.js?ver=1.12.4-wp",
#               "totalBytes": 40078
#             },
#             {
#               "wastedMs": 630,
#               "url": "https://www.deepcrawl.com/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1",
#               "totalBytes": 4984
#             },
#             {
#               "wastedMs": 780,
#               "url": "https://kit.fontawesome.com/98f8bc885f.js",
#               "totalBytes": 2688
#             }
#           ]
#         },
#         "numericValue": 1320
#       },
#       "uses-optimized-images": {
#         "id": "uses-optimized-images",
#         "title": "Efficiently encode images",
#         "description": "Optimized images load faster and consume less cellular data. [Learn more](https://web.dev/uses-optimized-images).",
#         "score": 1,
#         "scoreDisplayMode": "numeric",
#         "details": {
#           "type": "opportunity",
#           "overallSavingsBytes": 0,
#           "overallSavingsMs": 0
#         },
#         "numericValue": 0
#       },
#       "uses-text-compression": {
#         "id": "uses-text-compression",
#         "title": "Enable text compression",
#         "description": "Text-based resources should be served with compression (gzip, deflate or brotli) to minimize total network bytes. [Learn more](https://web.dev/uses-text-compression).",
#         "score": 1,
#         "scoreDisplayMode": "numeric",
#         "displayValue": "Potential savings of 3 KB",
#         "details": {
#           "overallSavingsMs": 0,
#           "headings": [
#             {
#               "key": "url",
#               "valueType": "url",
#               "label": "URL"
#             },
#             {
#               "valueType": "bytes",
#               "label": "Size",
#               "key": "totalBytes"
#             },
#             {
#               "key": "wastedBytes",
#               "valueType": "bytes",
#               "label": "Potential Savings"
#             }
#           ],
#           "type": "opportunity",
#           "items": [
#             {
#               "url": "https://marketing.deepcrawl.com/cdnr/202/acton/bn/tracker/31628",
#               "totalBytes": 4797,
#               "wastedBytes": 3154
#             }
#           ],
#           "overallSavingsBytes": 3154
#         },
#         "numericValue": 0
#       },
#       "network-requests": {
#         "id": "network-requests",
#         "title": "Network Requests",
#         "description": "Lists the network requests that were made during page load.",
#         "score": null,
#         "scoreDisplayMode": "informative",
#         "details": {
#           "headings": [
#             {
#               "text": "URL",
#               "key": "url",
#               "itemType": "url"
#             },
#             {
#               "key": "startTime",
#               "itemType": "ms",
#               "text": "Start Time",
#               "granularity": 1
#             },
#             {
#               "text": "End Time",
#               "granularity": 1,
#               "key": "endTime",
#               "itemType": "ms"
#             },
#             {
#               "key": "transferSize",
#               "itemType": "bytes",
#               "text": "Transfer Size",
#               "granularity": 1,
#               "displayUnit": "kb"
#             },
#             {
#               "key": "resourceSize",
#               "itemType": "bytes",
#               "text": "Resource Size",
#               "displayUnit": "kb",
#               "granularity": 1
#             },
#             {
#               "key": "statusCode",
#               "itemType": "text",
#               "text": "Status Code"
#             },
#             {
#               "key": "mimeType",
#               "itemType": "text",
#               "text": "MIME Type"
#             },
#             {
#               "key": "resourceType",
#               "itemType": "text",
#               "text": "Resource Type"
#             }
#           ],
#           "type": "table",
#           "items": [
#             {
#               "mimeType": "text/html",
#               "endTime": 548.81699997349642,
#               "resourceSize": 0,
#               "startTime": 0,
#               "transferSize": 684,
#               "url": "https://www.deepcrawl.com//",
#               "statusCode": 301
#             },
#             {
#               "startTime": 549.2789999989327,
#               "transferSize": 17108,
#               "statusCode": 200,
#               "url": "https://www.deepcrawl.com/",
#               "resourceType": "Document",
#               "mimeType": "text/html",
#               "resourceSize": 61653,
#               "endTime": 817.51599998096935
#             },
#             {
#               "endTime": 905.52299999399111,
#               "resourceSize": 29295,
#               "startTime": 838.95299999858253,
#               "transferSize": 6553,
#               "url": "https://www.deepcrawl.com/wp-includes/css/dist/block-library/style.min.css?ver=5.2.4",
#               "statusCode": 200,
#               "resourceType": "Stylesheet",
#               "mimeType": "text/css"
#             },
#             {
#               "transferSize": 31007,
#               "url": "https://www.deepcrawl.com/wp-content/themes/deepcrawl/build/styles.min.css?ver=5.2.2.1",
#               "statusCode": 200,
#               "resourceType": "Stylesheet",
#               "mimeType": "text/css",
#               "resourceSize": 178027,
#               "endTime": 875.51999997231178,
#               "startTime": 839.13299997220747
#             },
#             {
#               "resourceType": "Script",
#               "mimeType": "application/x-javascript",
#               "resourceSize": 96873,
#               "endTime": 906.312999984948,
#               "startTime": 839.46499999728985,
#               "transferSize": 40078,
#               "url": "https://www.deepcrawl.com/wp-includes/js/jquery/jquery.js?ver=1.12.4-wp",
#               "statusCode": 200
#             },
#             {
#               "mimeType": "application/x-javascript",
#               "endTime": 897.49499998288229,
#               "resourceSize": 10056,
#               "startTime": 840.01899999566376,
#               "transferSize": 4984,
#               "statusCode": 200,
#               "url": "https://www.deepcrawl.com/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1",
#               "resourceType": "Script"
#             },
#             {
#               "endTime": 989.40899997251108,
#               "resourceSize": 5783,
#               "startTime": 840.23799997521564,
#               "transferSize": 2688,
#               "statusCode": 200,
#               "url": "https://kit.fontawesome.com/98f8bc885f.js",
#               "resourceType": "Script",
#               "mimeType": "text/javascript"
#             },
#             {
#               "transferSize": 2588,
#               "url": "https://www.deepcrawl.com/wp-content/themes/deepcrawl/images/deepcrawl-logo.svg",
#               "statusCode": 200,
#               "resourceType": "Image",
#               "mimeType": "image/svg+xml",
#               "resourceSize": 5505,
#               "endTime": 900.96599998651072,
#               "startTime": 841.08799998648465
#             },
#             {
#               "startTime": 841.39999997569248,
#               "transferSize": 3991,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/02/hp-grey-made.png",
#               "statusCode": 200,
#               "resourceType": "Image",
#               "mimeType": "image/png",
#               "resourceSize": 3379,
#               "endTime": 907.177999994019
#             },
#             {
#               "transferSize": 4564,
#               "statusCode": 200,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/04/groupM.png",
#               "resourceType": "Image",
#               "mimeType": "image/png",
#               "resourceSize": 3952,
#               "endTime": 1023.256999993464,
#               "startTime": 963.35899998666719
#             },
#             {
#               "resourceType": "Image",
#               "mimeType": "image/png",
#               "endTime": 1000.0649999710731,
#               "resourceSize": 2046,
#               "startTime": 980.7509999955073,
#               "transferSize": 2659,
#               "statusCode": 200,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/04/Ikea.png"
#             },
#             {
#               "startTime": 994.14599998272024,
#               "transferSize": 4439,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/04/Shopify.png",
#               "statusCode": 200,
#               "resourceType": "Image",
#               "mimeType": "image/png",
#               "resourceSize": 3826,
#               "endTime": 1013.5969999828376
#             },
#             {
#               "mimeType": "image/svg+xml",
#               "resourceSize": 1907,
#               "endTime": 1011.7999999783933,
#               "startTime": 994.362999976147,
#               "transferSize": 1340,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/02/black-buildings.svg",
#               "statusCode": 200,
#               "resourceType": "Image"
#             },
#             {
#               "resourceType": "Image",
#               "mimeType": "image/svg+xml",
#               "endTime": 1052.3689999827184,
#               "resourceSize": 1148,
#               "startTime": 994.51499999850057,
#               "transferSize": 1220,
#               "statusCode": 200,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/02/black-map-poing.svg"
#             },
#             {
#               "startTime": 994.82399999396876,
#               "transferSize": 1159,
#               "statusCode": 200,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/02/black-masonry.svg",
#               "resourceType": "Image",
#               "mimeType": "image/svg+xml",
#               "endTime": 1012.5809999881312,
#               "resourceSize": 967
#             },
#             {
#               "resourceType": "Image",
#               "mimeType": "image/svg+xml",
#               "endTime": 1054.8179999750573,
#               "resourceSize": 1045,
#               "startTime": 995.266999991145,
#               "transferSize": 1216,
#               "statusCode": 200,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/02/black-ticks.svg"
#             },
#             {
#               "startTime": 995.39099997491576,
#               "transferSize": 1272,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/02/mobile-check.svg",
#               "statusCode": 200,
#               "resourceType": "Image",
#               "mimeType": "image/svg+xml",
#               "resourceSize": 1315,
#               "endTime": 1053.9969999808818
#             },
#             {
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/02/fast-forward.svg",
#               "statusCode": 200,
#               "resourceType": "Image",
#               "mimeType": "image/svg+xml",
#               "endTime": 1054.4239999726415,
#               "resourceSize": 880,
#               "startTime": 995.50999997882172,
#               "transferSize": 1141
#             },
#             {
#               "resourceType": "Image",
#               "mimeType": "image/svg+xml",
#               "resourceSize": 1026,
#               "endTime": 1057.2809999866877,
#               "startTime": 995.68799999542534,
#               "transferSize": 1244,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/02/se-functionality.svg",
#               "statusCode": 200
#             },
#             {
#               "statusCode": 200,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/02/list.svg",
#               "resourceType": "Image",
#               "mimeType": "image/svg+xml",
#               "endTime": 1055.6189999915659,
#               "resourceSize": 1255,
#               "startTime": 995.887999975821,
#               "transferSize": 1194
#             },
#             {
#               "resourceType": "Image",
#               "mimeType": "image/svg+xml",
#               "endTime": 1053.5349999845494,
#               "resourceSize": 865,
#               "startTime": 996.01099998108111,
#               "transferSize": 1151,
#               "statusCode": 200,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/02/amp-blue.svg"
#             },
#             {
#               "mimeType": "image/svg+xml",
#               "resourceSize": 1216,
#               "endTime": 1014.6139999851584,
#               "startTime": 996.20299998787232,
#               "transferSize": 1203,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/02/blue-list.svg",
#               "statusCode": 200,
#               "resourceType": "Image"
#             },
#             {
#               "mimeType": "image/svg+xml",
#               "resourceSize": 1154,
#               "endTime": 1055.2379999717232,
#               "startTime": 996.38899997808039,
#               "transferSize": 1234,
#               "statusCode": 200,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/02/blue-text.svg",
#               "resourceType": "Image"
#             },
#             {
#               "resourceType": "Image",
#               "mimeType": "image/svg+xml",
#               "endTime": 1063.9069999742787,
#               "resourceSize": 1042,
#               "startTime": 996.52699998114258,
#               "transferSize": 1167,
#               "statusCode": 200,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/02/blue-reports.svg"
#             },
#             {
#               "mimeType": "image/svg+xml",
#               "endTime": 1056.0649999824818,
#               "resourceSize": 1103,
#               "startTime": 996.69299999368377,
#               "transferSize": 1208,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/02/teal-pie.svg",
#               "statusCode": 200,
#               "resourceType": "Image"
#             },
#             {
#               "statusCode": 200,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/02/teal-table.svg",
#               "resourceType": "Image",
#               "mimeType": "image/svg+xml",
#               "endTime": 1015.0249999715015,
#               "resourceSize": 1192,
#               "startTime": 996.91699998220429,
#               "transferSize": 1234
#             },
#             {
#               "resourceType": "Image",
#               "mimeType": "image/svg+xml",
#               "endTime": 1028.9339999726508,
#               "resourceSize": 1425,
#               "startTime": 997.58499997551553,
#               "transferSize": 1299,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/02/teal-magnifying-glass.svg",
#               "statusCode": 200
#             },
#             {
#               "transferSize": 1584,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/02/teal-monitor.svg",
#               "statusCode": 200,
#               "resourceType": "Image",
#               "mimeType": "image/svg+xml",
#               "resourceSize": 1926,
#               "endTime": 1058.9079999772366,
#               "startTime": 997.69499999820255
#             },
#             {
#               "startTime": 997.82499999855645,
#               "transferSize": 2111,
#               "statusCode": 200,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/02/Screen-Shot-2019-06-25-at-17.52.35-60x40.png",
#               "resourceType": "Image",
#               "mimeType": "image/png",
#               "endTime": 1016.5809999743942,
#               "resourceSize": 1499
#             },
#             {
#               "statusCode": 200,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/02/395-5-60x40.png",
#               "resourceType": "Image",
#               "mimeType": "image/png",
#               "resourceSize": 817,
#               "endTime": 1056.7969999974594,
#               "startTime": 997.96799998148344,
#               "transferSize": 1428
#             },
#             {
#               "resourceType": "Image",
#               "mimeType": "image/jpeg",
#               "endTime": 1059.5529999991413,
#               "resourceSize": 4324,
#               "startTime": 998.16999997710809,
#               "transferSize": 4939,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/06/migros-300x198.jpg",
#               "statusCode": 200
#             },
#             {
#               "resourceSize": 2742,
#               "endTime": 1058.6169999733102,
#               "startTime": 998.3609999762848,
#               "transferSize": 3355,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/02/peak-ace-logo-60x40.png",
#               "statusCode": 200,
#               "resourceType": "Image",
#               "mimeType": "image/png"
#             },
#             {
#               "resourceType": "Image",
#               "mimeType": "image/png",
#               "resourceSize": 1813,
#               "endTime": 1057.93999999878,
#               "startTime": 998.48199999541976,
#               "transferSize": 2425,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/06/Untitled-design-1-60x40.png",
#               "statusCode": 200
#             },
#             {
#               "transferSize": 2283,
#               "statusCode": 200,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/02/All_0000_Hotter-385-60x40.png",
#               "resourceType": "Image",
#               "mimeType": "image/png",
#               "resourceSize": 1670,
#               "endTime": 1062.2869999788236,
#               "startTime": 998.6279999720864
#             },
#             {
#               "transferSize": 5122,
#               "statusCode": 200,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/08/impression-logo-1.jpg",
#               "resourceType": "Image",
#               "mimeType": "image/jpeg",
#               "resourceSize": 4507,
#               "endTime": 1064.5279999880586,
#               "startTime": 998.80899998242967
#             },
#             {
#               "resourceSize": 6393,
#               "endTime": 1059.8819999722764,
#               "startTime": 998.92999997246079,
#               "transferSize": 7008,
#               "statusCode": 200,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/03/dc-nick-150x150.jpg",
#               "resourceType": "Image",
#               "mimeType": "image/jpeg"
#             },
#             {
#               "transferSize": 3526,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/03/dc-bartoz-150x150.jpg",
#               "statusCode": 200,
#               "resourceType": "Image",
#               "mimeType": "image/jpeg",
#               "resourceSize": 2913,
#               "endTime": 1060.6119999720249,
#               "startTime": 999.06399997416884
#             },
#             {
#               "endTime": 1058.2699999795295,
#               "resourceSize": 4999,
#               "startTime": 999.20599997858517,
#               "transferSize": 5613,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/03/dc-test-lauren-150x150.jpg",
#               "statusCode": 200,
#               "resourceType": "Image",
#               "mimeType": "image/jpeg"
#             },
#             {
#               "endTime": 1059.1779999958817,
#               "resourceSize": 4033,
#               "startTime": 999.33499997132458,
#               "transferSize": 4647,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/03/dc-tom-150x150.jpeg",
#               "statusCode": 200,
#               "resourceType": "Image",
#               "mimeType": "image/jpeg"
#             },
#             {
#               "resourceType": "Image",
#               "mimeType": "image/jpeg",
#               "endTime": 1060.2419999777339,
#               "resourceSize": 4567,
#               "startTime": 999.48999998741783,
#               "transferSize": 5182,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/03/dc-sam-150x150.jpg",
#               "statusCode": 200
#             },
#             {
#               "resourceType": "Image",
#               "mimeType": "image/png",
#               "resourceSize": 18640,
#               "endTime": 1074.4499999855179,
#               "startTime": 999.61999998777173,
#               "transferSize": 19255,
#               "statusCode": 200,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/03/dc-andor-palau-150x150.png"
#             },
#             {
#               "statusCode": 200,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/03/jared-gardner-150x150.jpeg",
#               "resourceType": "Image",
#               "mimeType": "image/jpeg",
#               "endTime": 1061.1149999895133,
#               "resourceSize": 3641,
#               "startTime": 1001.533999980893,
#               "transferSize": 4255
#             },
#             {
#               "mimeType": "image/jpeg",
#               "endTime": 1063.5789999796543,
#               "resourceSize": 10002,
#               "startTime": 1001.6709999763407,
#               "transferSize": 10618,
#               "statusCode": 200,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/03/dc-jordan.jpeg",
#               "resourceType": "Image"
#             },
#             {
#               "transferSize": 5972,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/03/dc-arsen-150x150.jpg",
#               "statusCode": 200,
#               "resourceType": "Image",
#               "mimeType": "image/jpeg",
#               "endTime": 1064.2249999800697,
#               "resourceSize": 5358,
#               "startTime": 1001.8019999843091
#             },
#             {
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/12/QeKSxXQJ_400x400-1-150x150.jpg",
#               "statusCode": 200,
#               "resourceType": "Image",
#               "mimeType": "image/jpeg",
#               "resourceSize": 3603,
#               "endTime": 1062.6029999984894,
#               "startTime": 1001.9659999816213,
#               "transferSize": 4217
#             },
#             {
#               "endTime": 1061.8879999965429,
#               "resourceSize": 4050,
#               "startTime": 1002.0979999972042,
#               "transferSize": 4664,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/05/Casie-Gillette-Headshot-2017-150x150.jpg",
#               "statusCode": 200,
#               "resourceType": "Image",
#               "mimeType": "image/jpeg"
#             },
#             {
#               "startTime": 1002.2289999760687,
#               "transferSize": 5530,
#               "statusCode": 200,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/03/dc-gulf-150x150.jpg",
#               "resourceType": "Image",
#               "mimeType": "image/jpeg",
#               "resourceSize": 4916,
#               "endTime": 1062.9399999743327
#             },
#             {
#               "mimeType": "image/jpeg",
#               "endTime": 1061.5219999745023,
#               "resourceSize": 3566,
#               "startTime": 1002.4839999969117,
#               "transferSize": 4179,
#               "statusCode": 200,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/05/maria-onely-150x150.jpg",
#               "resourceType": "Image"
#             },
#             {
#               "resourceType": "Image",
#               "mimeType": "image/jpeg",
#               "resourceSize": 5631,
#               "endTime": 1063.2789999945089,
#               "startTime": 1002.6199999847449,
#               "transferSize": 6246,
#               "statusCode": 200,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2019/12/Igal-Stolpner-Investing.com_-e1575637122336-150x150.jpg"
#             },
#             {
#               "transferSize": 18526,
#               "url": "https://www.deepcrawl.com/wp-content/uploads/2020/02/Google-Webmaster-Hangout_Short_No_Text-768x307.jpg",
#               "statusCode": 200,
#               "resourceType": "Image",
#               "mimeType": "image/jpeg",
#               "resourceSize": 17911,
#               "endTime": 1077.4679999740329,
#               "startTime": 1002.7359999949113
#             },
#             {
#               "statusCode": 200,
# ...
#           "type": "debugdata",
#           "items": [
#             {
#               "numTasksOver500ms": 0,
#               "numScripts": 25,
#               "maxServerLatency": null,
#               "numStylesheets": 5,
#               "numTasksOver100ms": 3,
#               "throughput": 35586861435.062622,
#               "numTasksOver25ms": 9,
#               "numTasksOver50ms": 3,
#               "numRequests": 112,
#               "totalTaskTime": 1220.6550000000022,
#               "mainDocumentTransferSize": 17108,
#               "totalByteWeight": 1132622,
#               "numTasks": 1074,
#               "numTasksOver10ms": 18,
#               "rtt": 0.00051558239258955906,
#               "numFonts": 2,
#               "maxRtt": 0.00051558239258955906
#             }
#           ]
#         }
#       }
#     },
#     "categories": {
#       "performance": {
#         "id": "performance",
#         "title": "Performance",
#         "score": 0.55,
#         "auditRefs": [
#           {
#             "id": "first-contentful-paint",
#             "weight": 3,
#             "group": "metrics"
#           },
#           {
#             "id": "first-meaningful-paint",
#             "weight": 1,
#             "group": "metrics"
#           },
#           {
#             "id": "speed-index",
#             "weight": 4,
#             "group": "metrics"
#           },
#           {
#             "id": "interactive",
#             "weight": 5,
#             "group": "metrics"
#           },
#           {
#             "id": "first-cpu-idle",
#             "weight": 2,
#             "group": "metrics"
#           },
#           {
#             "id": "max-potential-fid",
#             "weight": 0,
#             "group": "metrics"
#           },
#           {
#             "id": "estimated-input-latency",
#             "weight": 0
#           },
#           {
#             "id": "total-blocking-time",
#             "weight": 0
#           },
#           {
#             "id": "render-blocking-resources",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "uses-responsive-images",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "offscreen-images",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "unminified-css",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "unminified-javascript",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "unused-css-rules",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "uses-optimized-images",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "uses-webp-images",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "uses-text-compression",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "uses-rel-preconnect",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "time-to-first-byte",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "redirects",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "uses-rel-preload",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "efficient-animated-content",
#             "weight": 0,
#             "group": "load-opportunities"
#           },
#           {
#             "id": "total-byte-weight",
#             "weight": 0,
#             "group": "diagnostics"
#           },
#           {
#             "id": "uses-long-cache-ttl",
#             "weight": 0,
#             "group": "diagnostics"
#           },
#           {
#             "id": "dom-size",
#             "weight": 0,
#             "group": "diagnostics"
#           },
#           {
#             "id": "critical-request-chains",
#             "weight": 0,
#             "group": "diagnostics"
#           },
#           {
#             "id": "user-timings",
#             "weight": 0,
#             "group": "diagnostics"
#           },
#           {
#             "id": "bootup-time",
#             "weight": 0,
#             "group": "diagnostics"
#           },
#           {
#             "id": "mainthread-work-breakdown",
#             "weight": 0,
#             "group": "diagnostics"
#           },
#           {
#             "id": "font-display",
#             "weight": 0,
#             "group": "diagnostics"
#           },
#           {
#             "id": "performance-budget",
#             "weight": 0,
#             "group": "budgets"
#           },
#           {
#             "id": "resource-summary",
#             "weight": 0,
#             "group": "diagnostics"
#           },
#           {
#             "id": "third-party-summary",
#             "weight": 0,
#             "group": "diagnostics"
#           },
#           {
#             "id": "network-requests",
#             "weight": 0
#           },
#           {
#             "id": "network-rtt",
#             "weight": 0
#           },
#           {
#             "id": "network-server-latency",
#             "weight": 0
#           },
#           {
#             "id": "main-thread-tasks",
#             "weight": 0
#           },
#           {
#             "id": "diagnostics",
#             "weight": 0
#           },
#           {
#             "id": "metrics",
#             "weight": 0
#           },
#           {
#             "id": "screenshot-thumbnails",
#             "weight": 0
#           },
#           {
#             "id": "final-screenshot",
#             "weight": 0
#           },
#           {
#             "id": "first-contentful-paint-3g",
#             "weight": 0
#           }
#         ]
#       }
#     },
#     "categoryGroups": {
#       "diagnostics": {
#         "title": "Diagnostics",
#         "description": "More information about the performance of your application. These numbers don't [directly affect](https://github.com/GoogleChrome/lighthouse/blob/d2ec9ffbb21de9ad1a0f86ed24575eda32c796f0/docs/scoring.md#how-are-the-scores-weighted) the Performance score."
#       },
#       "a11y-best-practices": {
#         "title": "Best practices",
#         "description": "These items highlight common accessibility best practices."
#       },
#       "a11y-color-contrast": {
#         "title": "Contrast",
#         "description": "These are opportunities to improve the legibility of your content."
#       },
#       "seo-crawl": {
#         "title": "Crawling and Indexing",
#         "description": "To appear in search results, crawlers need access to your app."
#       },
#       "seo-content": {
#         "title": "Content Best Practices",
#         "description": "Format your HTML in a way that enables crawlers to better understand your app’s content."
#       },
#       "pwa-optimized": {
#         "title": "PWA Optimized"
#       },
#       "a11y-navigation": {
#         "title": "Navigation",
#         "description": "These are opportunities to improve keyboard navigation in your application."
#       },
#       "pwa-fast-reliable": {
#         "title": "Fast and reliable"
#       },
#       "a11y-aria": {
#         "title": "ARIA",
#         "description": "These are opportunities to improve the usage of ARIA in your application which may enhance the experience for users of assistive technology, like a screen reader."
#       },
#       "a11y-audio-video": {
#         "title": "Audio and video",
#         "description": "These are opportunities to provide alternative content for audio and video. This may improve the experience for users with hearing or vision impairments."
#       },
#       "a11y-language": {
#         "title": "Internationalization and localization",
#         "description": "These are opportunities to improve the interpretation of your content by users in different locales."
#       },
#       "a11y-tables-lists": {
#         "title": "Tables and lists",
#         "description": "These are opportunities to to improve the experience of reading tabular or list data using assistive technology, like a screen reader."
#       },
#       "a11y-names-labels": {
#         "title": "Names and labels",
#         "description": "These are opportunities to improve the semantics of the controls in your application. This may enhance the experience for users of assistive technology, like a screen reader."
#       },
#       "budgets": {
#         "title": "Budgets",
#         "description": "Performance budgets set standards for the performance of your site."
#       },
#       "load-opportunities": {
#         "title": "Opportunities",
#         "description": "These suggestions can help your page load faster. They don't [directly affect](https://github.com/GoogleChrome/lighthouse/blob/d2ec9ffbb21de9ad1a0f86ed24575eda32c796f0/docs/scoring.md#how-are-the-scores-weighted) the Performance score."
#       },
#       "metrics": {
#         "title": "Metrics"
#       },
#       "pwa-installable": {
#         "title": "Installable"
#       },
#       "seo-mobile": {
#         "title": "Mobile Friendly",
#         "description": "Make sure your pages are mobile friendly so users don’t have to pinch or zoom in order to read the content pages. [Learn more](https://developers.google.com/search/mobile-sites/)."
#       }
#     },
#     "timing": {
#       "total": 8304.73
#     },
#     "i18n": {
#       "rendererFormattedStrings": {
#         "varianceDisclaimer": "Values are estimated and may vary. The performance score is [based only on these metrics](https://github.com/GoogleChrome/lighthouse/blob/d2ec9ffbb21de9ad1a0f86ed24575eda32c796f0/docs/scoring.md#how-are-the-scores-weighted).",
#         "opportunityResourceColumnLabel": "Opportunity",
#         "opportunitySavingsColumnLabel": "Estimated Savings",
#         "errorMissingAuditInfo": "Report error: no audit information",
#         "errorLabel": "Error!",
#         "warningHeader": "Warnings: ",
#         "auditGroupExpandTooltip": "Show audits",
#         "passedAuditsGroupTitle": "Passed audits",
#         "notApplicableAuditsGroupTitle": "Not applicable",
#         "manualAuditsGroupTitle": "Additional items to manually check",
#         "toplevelWarningsMessage": "There were issues affecting this run of Lighthouse:",
#         "crcLongestDurationLabel": "Maximum critical path latency:",
#         "crcInitialNavigation": "Initial Navigation",
#         "lsPerformanceCategoryDescription": "[Lighthouse](https://developers.google.com/web/tools/lighthouse/) analysis of the current page on an emulated mobile network. Values are estimated and may vary.",
#         "labDataTitle": "Lab Data"
#       }
#     },
#     "stackPacks": [
#       {
#         "id": "wordpress",
#         "title": "WordPress",
#         "iconDataURL": "data:image/svg+xml,%3Csvg viewBox='0 0 122.5 122.5' xmlns='http://www.w3.org/2000/svg'%3E%3Cg fill='%232f3439'%3E%3Cpath d='M8.7 61.3c0 20.8 12.1 38.7 29.6 47.3l-25-68.7c-3 6.5-4.6 13.7-4.6 21.4zM96.7 58.6c0-6.5-2.3-11-4.3-14.5-2.7-4.3-5.2-8-5.2-12.3 0-4.8 3.7-9.3 8.9-9.3h.7a52.4 52.4 0 0 0-79.4 9.9h3.3c5.5 0 14-.6 14-.6 2.9-.2 3.2 4 .4 4.3 0 0-2.9.4-6 .5l19.1 57L59.7 59l-8.2-22.5c-2.8-.1-5.5-.5-5.5-.5-2.8-.1-2.5-4.5.3-4.3 0 0 8.7.7 13.9.7 5.5 0 14-.7 14-.7 2.8-.2 3.2 4 .3 4.3 0 0-2.8.4-6 .5l19 56.5 5.2-17.5c2.3-7.3 4-12.5 4-17z'/%3E%3Cpath d='M62.2 65.9l-15.8 45.8a52.6 52.6 0 0 0 32.3-.9l-.4-.7zM107.4 36a49.6 49.6 0 0 1-3.6 24.2l-16.1 46.5A52.5 52.5 0 0 0 107.4 36z'/%3E%3Cpath d='M61.3 0a61.3 61.3 0 1 0 .1 122.7A61.3 61.3 0 0 0 61.3 0zm0 119.7a58.5 58.5 0 1 1 .1-117 58.5 58.5 0 0 1-.1 117z'/%3E%3C/g%3E%3C/svg%3E",
#         "descriptions": {
#           "time-to-first-byte": "Themes, plugins, and server specifications all contribute to server response time. Consider finding a more optimized theme, carefully selecting an optimization plugin, and/or upgrading your server.",
#           "total-byte-weight": "Consider showing excerpts in your post lists (e.g. via the more tag), reducing the number of posts shown on a given page, breaking your long posts into multiple pages, or using a plugin to lazy-load comments.",
#           "render-blocking-resources": "There are a number of WordPress plugins that can help you [inline critical assets](https://wordpress.org/plugins/search/critical+css/) or [defer less important resources](https://wordpress.org/plugins/search/defer+css+javascript/). Beware that optimizations provided by these plugins may break features of your theme or plugins, so you will likely need to make code changes.",
#           "uses-optimized-images": "Consider using an [image optimization WordPress plugin](https://wordpress.org/plugins/search/optimize+images/) that compresses your images while retaining quality.",
#           "uses-text-compression": "You can enable text compression in your web server configuration.",
#           "uses-webp-images": "Consider using a [plugin](https://wordpress.org/plugins/search/convert+webp/) or service that will automatically convert your uploaded images to the optimal formats.",
#           "uses-long-cache-ttl": "Read about [Browser Caching in WordPress](https://codex.wordpress.org/WordPress_Optimization#Browser_Caching).",
#           "unused-javascript": "Consider reducing, or switching, the number of [WordPress plugins](https://wordpress.org/plugins/) loading unused JavaScript in your page. To identify plugins that are adding extraneous JS, try running [code coverage](https://developers.google.com/web/updates/2017/04/devtools-release-notes#coverage) in Chrome DevTools. You can identify the theme/plugin responsible from the URL of the script. Look out for plugins that have many scripts in the list which have a lot of red in code coverage. A plugin should only enqueue a script if it is actually used on the page.",
#           "unminified-javascript": "A number of [WordPress plugins](https://wordpress.org/plugins/search/minify+javascript/) can speed up your site by concatenating, minifying, and compressing your scripts. You may also want to use a build process to do this minification up front if possible.",
#           "unminified-css": "A number of [WordPress plugins](https://wordpress.org/plugins/search/minify+css/) can speed up your site by concatenating, minifying, and compressing your styles. You may also want to use a build process to do this minification up-front if possible.",
#           "offscreen-images": "Install a [lazy-load WordPress plugin](https://wordpress.org/plugins/search/lazy+load/) that provides the ability to defer any offscreen images, or switch to a theme that provides that functionality. Also consider using [the AMP plugin](https://wordpress.org/plugins/amp/).",
#           "uses-responsive-images": "Upload images directly through the [media library](https://codex.wordpress.org/Media_Library_Screen) to ensure that the required image sizes are available, and then insert them from the media library or use the image widget to ensure the optimal image sizes are used (including those for the responsive breakpoints). Avoid using `Full Size` images unless the dimensions are adequate for their usage. [Learn More](https://codex.wordpress.org/Inserting_Images_into_Posts_and_Pages#Image_Size).",
#           "efficient-animated-content": "Consider uploading your GIF to a service which will make it available to embed as an HTML5 video.",
#           "unused-css-rules": "Consider reducing, or switching, the number of [WordPress plugins](https://wordpress.org/plugins/) loading unused CSS in your page. To identify plugins that are adding extraneous CSS, try running [code coverage](https://developers.google.com/web/updates/2017/04/devtools-release-notes#coverage) in Chrome DevTools. You can identify the theme/plugin responsible from the URL of the stylesheet. Look out for plugins that have many stylesheets in the list which have a lot of red in code coverage. A plugin should only enqueue a stylesheet if it is actually used on the page."
#         }
#       }
#     ]
#   },
#   "analysisUTCTimestamp": "2020-03-02T21:06:00.341Z"
# }

# %% [markdown]
# **Optional Step:** Converting to JSON format to download and analyse for single URL

# %%
# Convert to json format
result_json = json.loads(result)

print(result_json)

with open('result.json', 'w') as outfile:
  json.dump(result_json, outfile)

files.download('result.json')

# %% [markdown]
# Upload a csv file of URLs, ensure the column header is titled 'url' (if not, please define the column header as the variable where instructed)

# %%
uploaded = files.upload()
#if your column header is something other than 'url' please define it here 
column_header='url'
# Out:
#      <input type="file" id="files-2bd2f391-8e70-416e-b30e-57ab915e25f9" name="files[]" multiple disabled />
#      <output id="result-2bd2f391-8e70-416e-b30e-57ab915e25f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving urls.csv to urls.csv

# %% [markdown]
# Turning csv file into a Pandas dataframe and reviewing

# %%
# Get the filename from the upload so we can read it into a CSV.
for key in uploaded.keys():
  filename = key
# Read the selected file into a Pandas Dataframe
df = pd.read_csv(io.BytesIO(uploaded[filename]))

df.head()
# Out:
#                                                  url
# 0                         https://www.deepcrawl.com/
# 1                 https://www.deepcrawl.com/pricing/
# 2                    https://www.deepcrawl.com/blog/
# 3  https://www.deepcrawl.com/knowledge/hangout-li...
# 4  https://www.deepcrawl.com/knowledge/getting-st...

# %% [markdown]
# Iterate through the list of URLs to run through the Page Speed API *(please note this step may take some time to complete, as we have added a 30 second break between URLs to prevent overloading the API)*

# %%
response_object = {}


# Iterate through the df
for i in range(0, len(df)):

        #print('Requesting row #:', i)

        # Define request parameter
        url = df.iloc[i][column_header]

        # Make request
        pagespeed_results = urllib.request.urlopen('https://www.googleapis.com/pagespeedonline/v5/runPagespeed?url={}&strategy=mobile'\
            .format(url)).read().decode('UTF-8')

        # Convert to json format
        pagespeed_results_json = json.loads(pagespeed_results)

        # Insert returned json response into response_object
        response_object[url] = pagespeed_results_json
        time.sleep(30)
        
        print(response_object[url])

        #Optional download of json files, comment out to skip this step 
        #with open('pagespeed_results_json', 'w') as outfile:
            #json.dump(response_object[url], outfile)
        
        #files.download('pagespeed_results_json')
# Out:
# {'captchaResult': 'CAPTCHA_NOT_NEEDED', 'kind': 'pagespeedonline#result', 'id': 'https://www.deepcrawl.com/', 'loadingExperience': {'id': 'https://www.deepcrawl.com/', 'metrics': {'FIRST_CONTENTFUL_PAINT_MS': {'percentile': 2246, 'distributions': [{'min': 0, 'max': 1000, 'proportion': 0.323170731707317}, {'min': 1000, 'max': 3000, 'proportion': 0.5365853658536586}, {'min': 3000, 'proportion': 0.14024390243902438}], 'category': 'AVERAGE'}, 'FIRST_INPUT_DELAY_MS': {'percentile': 107, 'distributions': [{'min': 0, 'max': 100, 'proportion': 0.9344262295081969}, {'min': 100, 'max': 300, 'proportion': 0.05737704918032788}, {'min': 300, 'proportion': 0.00819672131147541}], 'category': 'AVERAGE'}}, 'overall_category': 'AVERAGE', 'initial_url': 'https://www.deepcrawl.com/'}, 'originLoadingExperience': {'id': 'https://www.deepcrawl.com', 'metrics': {'FIRST_CONTENTFUL_PAINT_MS': {'percentile': 2792, 'distributions': [{'min': 0, 'max': 1000, 'proportion': 0.23867069486404832}, {'min': 1000, 'max': 3000, 'proportion': 0.5400302114803626}, {'min': 3000, 'proportion': 0.22129909365558914}], 'category': 'AVERAGE'}, 'FIRST_INPUT_DELAY_MS': {'percentile': 234, 'distributions': [{'min': 0, 'max': 100, 'proportion': 0.8906474820143885}, {'min': 100, 'max': 300, 'proportion': 0.09640287769784173}, {'min': 300, 'proportion': 0.012949640287769782}], 'category': 'AVERAGE'}}, 'overall_category': 'AVERAGE', 'initial_url': 'https://www.deepcrawl.com/'}, 'lighthouseResult': {'requestedUrl': 'https://www.deepcrawl.com/', 'finalUrl': 'https://www.deepcrawl.com/', 'lighthouseVersion': '5.6.0', 'userAgent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/79.0.3945.120 Safari/537.36', 'fetchTime': '2020-03-01T17:02:07.677Z', 'environment': {'networkUserAgent': 'Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3694.0 Mobile Safari/537.36 Chrome-Lighthouse', 'hostUserAgent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/79.0.3945.120 Safari/537.36', 'benchmarkIndex': 750}, 'runWarnings': [], 'configSettings': {'emulatedFormFactor': 'mobile', 'locale': 'en-US', 'onlyCategories': ['performance'], 'channel': 'lr'}, 'audits': {'offscreen-images': {'id': 'offscreen-images', 'title': 'Defer offscreen images', 'description': 'Consider lazy-loading offscreen and hidden images after all critical resources have finished loading to lower time to interactive. [Learn more](https://web.dev/offscreen-images).', 'score': 1, 'scoreDisplayMode': 'numeric', 'details': {'overallSavingsMs': 0, 'headings': [], 'items': [], 'type': 'opportunity', 'overallSavingsBytes': 0}, 'warnings': [], 'numericValue': 0}, 'network-server-latency': {'id': 'network-server-latency', 'title': 'Server Backend Latencies', 'description': "Server latencies can impact web performance. If the server latency of an origin is high, it's an indication the server is overloaded or has poor backend performance. [Learn more](https://hpbn.co/primer-on-web-performance/#analyzing-the-resource-waterfall).", 'score': None, 'scoreDisplayMode': 'informative', 'displayValue': '0\xa0ms', 'details': {'items': [], 'type': 'table', 'headings': []}, 'numericValue': 0}, 'uses-responsive-images': {'id': 'uses-responsive-images', 'title': 'Properly size images', 'description': 'Serve images that are appropriately-sized to save cellular data and improve load time. [Learn more](https://web.dev/uses-responsive-images).', 'score': 1, 'scoreDisplayMode': 'numeric', 'details': {'overallSavingsMs': 0, 'headings': [], 'items': [], 'type': 'opportunity', 'overallSavingsBytes': 0}, 'warnings': [], 'numericValue': 0}, 'speed-index': {'id': 'speed-index', 'title': 'Speed Index', 'description': 'Speed Index shows how quickly the contents of a page are visibly populated. [Learn more](https://web.dev/speed-index).', 'score': 0.79, 'scoreDisplayMode': 'numeric', 'displayValue': '4.1\xa0s', 'numericValue': 4119. ...
# {'captchaResult': 'CAPTCHA_NOT_NEEDED', 'kind': 'pagespeedonline#result', 'id': 'https://www.deepcrawl.com/pricing/', 'loadingExperience': {'id': 'https://www.deepcrawl.com', 'metrics': {'FIRST_CONTENTFUL_PAINT_MS': {'percentile': 2792, 'distributions': [{'min': 0, 'max': 1000, 'proportion': 0.23867069486404832}, {'min': 1000, 'max': 3000, 'proportion': 0.5400302114803626}, {'min': 3000, 'proportion': 0.22129909365558914}], 'category': 'AVERAGE'}, 'FIRST_INPUT_DELAY_MS': {'percentile': 234, 'distributions': [{'min': 0, 'max': 100, 'proportion': 0.8906474820143885}, {'min': 100, 'max': 300, 'proportion': 0.09640287769784173}, {'min': 300, 'proportion': 0.012949640287769782}], 'category': 'AVERAGE'}}, 'overall_category': 'AVERAGE', 'initial_url': 'https://www.deepcrawl.com/pricing/'}, 'originLoadingExperience': {'id': 'https://www.deepcrawl.com', 'metrics': {'FIRST_CONTENTFUL_PAINT_MS': {'percentile': 2792, 'distributions': [{'min': 0, 'max': 1000, 'proportion': 0.23867069486404832}, {'min': 1000, 'max': 3000, 'proportion': 0.5400302114803626}, {'min': 3000, 'proportion': 0.22129909365558914}], 'category': 'AVERAGE'}, 'FIRST_INPUT_DELAY_MS': {'percentile': 234, 'distributions': [{'min': 0, 'max': 100, 'proportion': 0.8906474820143885}, {'min': 100, 'max': 300, 'proportion': 0.09640287769784173}, {'min': 300, 'proportion': 0.012949640287769782}], 'category': 'AVERAGE'}}, 'overall_category': 'AVERAGE', 'initial_url': 'https://www.deepcrawl.com/pricing/'}, 'lighthouseResult': {'requestedUrl': 'https://www.deepcrawl.com/pricing/', 'finalUrl': 'https://www.deepcrawl.com/pricing/', 'lighthouseVersion': '5.6.0', 'userAgent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/79.0.3945.120 Safari/537.36', 'fetchTime': '2020-03-01T17:02:46.150Z', 'environment': {'networkUserAgent': 'Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3694.0 Mobile Safari/537.36 Chrome-Lighthouse', 'hostUserAgent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/79.0.3945.120 Safari/537.36', 'benchmarkIndex': 694}, 'runWarnings': [], 'configSettings': {'emulatedFormFactor': 'mobile', 'locale': 'en-US', 'onlyCategories': ['performance'], 'channel': 'lr'}, 'audits': {'metrics': {'id': 'metrics', 'title': 'Metrics', 'description': 'Collects all available metrics.', 'score': None, 'scoreDisplayMode': 'informative', 'details': {'type': 'debugdata', 'items': [{'observedLargestContentfulPaintTs': 2977105283363, 'observedFirstVisualChange': 354, 'observedLoadTs': 2977106113394, 'firstMeaningfulPaint': 3627, 'observedTraceEnd': 2955, 'observedFirstMeaningfulPaint': 519, 'observedTraceEndTs': 2977107294766, 'firstCPUIdle': 7961, 'observedFirstMeaningfulPaintTs': 2977104858130, 'observedDomContentLoaded': 819, 'observedFirstVisualChangeTs': 2977104693472, 'observedNavigationStart': 0, 'interactive': 8604, 'observedFirstContentfulPaintTs': 2977104690029, 'observedLoad': 1774, 'observedLastVisualChangeTs': 2977105710472, 'observedLargestContentfulPaint': 944, 'observedDomContentLoadedTs': 2977105158485, 'observedSpeedIndex': 539, 'estimatedInputLatency': 236, 'totalBlockingTime': 1527, 'observedFirstPaint': 351, 'observedLastVisualChange': 1371, 'firstContentfulPaint': 3098, 'observedFirstPaintTs': 2977104690029, 'speedIndex': 3602, 'observedSpeedIndexTs': 2977104878208, 'observedFirstContentfulPaint': 351, 'observedNavigationStartTs': 2977104339472}, {'lcpInvalidated': False}]}, 'numericValue': 8604}, 'time-to-first-byte': {'id': 'time-to-first-byte', 'title': 'Server response times are low (TTFB)', 'description': 'Time To First Byte identifies the time at which your server sends a response. [Learn more](https://web.dev/time-to-first-byte).', 'score': 1, 'scoreDisplayMode': 'binary', 'displayValue': 'Root document took 70\xa0ms', 'details': {'overallSavingsMs': -530.667, 'headings': [], 'items': [], 'type': 'opportunity'}, 'numericValue': ...
# {'captchaResult': 'CAPTCHA_NOT_NEEDED', 'kind': 'pagespeedonline#result', 'id': 'https://www.deepcrawl.com/blog/', 'loadingExperience': {'id': 'https://www.deepcrawl.com', 'metrics': {'FIRST_CONTENTFUL_PAINT_MS': {'percentile': 2792, 'distributions': [{'min': 0, 'max': 1000, 'proportion': 0.23867069486404832}, {'min': 1000, 'max': 3000, 'proportion': 0.5400302114803626}, {'min': 3000, 'proportion': 0.22129909365558914}], 'category': 'AVERAGE'}, 'FIRST_INPUT_DELAY_MS': {'percentile': 234, 'distributions': [{'min': 0, 'max': 100, 'proportion': 0.8906474820143885}, {'min': 100, 'max': 300, 'proportion': 0.09640287769784173}, {'min': 300, 'proportion': 0.012949640287769782}], 'category': 'AVERAGE'}}, 'overall_category': 'AVERAGE', 'initial_url': 'https://www.deepcrawl.com/blog/'}, 'originLoadingExperience': {'id': 'https://www.deepcrawl.com', 'metrics': {'FIRST_CONTENTFUL_PAINT_MS': {'percentile': 2792, 'distributions': [{'min': 0, 'max': 1000, 'proportion': 0.23867069486404832}, {'min': 1000, 'max': 3000, 'proportion': 0.5400302114803626}, {'min': 3000, 'proportion': 0.22129909365558914}], 'category': 'AVERAGE'}, 'FIRST_INPUT_DELAY_MS': {'percentile': 234, 'distributions': [{'min': 0, 'max': 100, 'proportion': 0.8906474820143885}, {'min': 100, 'max': 300, 'proportion': 0.09640287769784173}, {'min': 300, 'proportion': 0.012949640287769782}], 'category': 'AVERAGE'}}, 'overall_category': 'AVERAGE', 'initial_url': 'https://www.deepcrawl.com/blog/'}, 'lighthouseResult': {'requestedUrl': 'https://www.deepcrawl.com/blog/', 'finalUrl': 'https://www.deepcrawl.com/blog/', 'lighthouseVersion': '5.6.0', 'userAgent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/79.0.3945.120 Safari/537.36', 'fetchTime': '2020-03-01T17:03:25.455Z', 'environment': {'networkUserAgent': 'Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3694.0 Mobile Safari/537.36 Chrome-Lighthouse', 'hostUserAgent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/79.0.3945.120 Safari/537.36', 'benchmarkIndex': 834}, 'runWarnings': [], 'configSettings': {'emulatedFormFactor': 'mobile', 'locale': 'en-US', 'onlyCategories': ['performance'], 'channel': 'lr'}, 'audits': {'render-blocking-resources': {'id': 'render-blocking-resources', 'title': 'Eliminate render-blocking resources', 'description': 'Resources are blocking the first paint of your page. Consider delivering critical JS/CSS inline and deferring all non-critical JS/styles. [Learn more](https://web.dev/render-blocking-resources).', 'score': 0.47, 'scoreDisplayMode': 'numeric', 'displayValue': 'Potential savings of 1,020\xa0ms', 'details': {'headings': [{'key': 'url', 'valueType': 'url', 'label': 'URL'}, {'valueType': 'bytes', 'label': 'Size', 'key': 'totalBytes'}, {'key': 'wastedMs', 'valueType': 'timespanMs', 'label': 'Potential Savings'}], 'type': 'opportunity', 'items': [{'totalBytes': 6552, 'wastedMs': 480, 'url': 'https://www.deepcrawl.com/wp-includes/css/dist/block-library/style.min.css?ver=5.2.4'}, {'url': 'https://www.deepcrawl.com/wp-content/themes/deepcrawl/build/styles.min.css?ver=5.2.2.1', 'totalBytes': 31006, 'wastedMs': 1380}, {'wastedMs': 1530, 'url': 'https://www.deepcrawl.com/wp-includes/js/jquery/jquery.js?ver=1.12.4-wp', 'totalBytes': 40077}, {'totalBytes': 4983, 'wastedMs': 630, 'url': 'https://www.deepcrawl.com/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1'}, {'wastedMs': 780, 'url': 'https://kit.fontawesome.com/98f8bc885f.js', 'totalBytes': 2688}], 'overallSavingsMs': 1020}, 'numericValue': 1020}, 'uses-text-compression': {'id': 'uses-text-compression', 'title': 'Enable text compression', 'description': 'Text-based resources should be served with compression (gzip, deflate or brotli) to minimize total network bytes. [Learn more](https://web.dev/uses-text-compression).', 'score': 1, 'scoreDisplayMode': 'numeric', 'displayValue': 'Potential savings of 3\xa0KB', ...
# {'captchaResult': 'CAPTCHA_NOT_NEEDED', 'kind': 'pagespeedonline#result', 'id': 'https://www.deepcrawl.com/knowledge/hangout-library/', 'loadingExperience': {'id': 'https://www.deepcrawl.com', 'metrics': {'FIRST_CONTENTFUL_PAINT_MS': {'percentile': 2792, 'distributions': [{'min': 0, 'max': 1000, 'proportion': 0.23867069486404832}, {'min': 1000, 'max': 3000, 'proportion': 0.5400302114803626}, {'min': 3000, 'proportion': 0.22129909365558914}], 'category': 'AVERAGE'}, 'FIRST_INPUT_DELAY_MS': {'percentile': 234, 'distributions': [{'min': 0, 'max': 100, 'proportion': 0.8906474820143885}, {'min': 100, 'max': 300, 'proportion': 0.09640287769784173}, {'min': 300, 'proportion': 0.012949640287769782}], 'category': 'AVERAGE'}}, 'overall_category': 'AVERAGE', 'initial_url': 'https://www.deepcrawl.com/knowledge/hangout-library/'}, 'originLoadingExperience': {'id': 'https://www.deepcrawl.com', 'metrics': {'FIRST_CONTENTFUL_PAINT_MS': {'percentile': 2792, 'distributions': [{'min': 0, 'max': 1000, 'proportion': 0.23867069486404832}, {'min': 1000, 'max': 3000, 'proportion': 0.5400302114803626}, {'min': 3000, 'proportion': 0.22129909365558914}], 'category': 'AVERAGE'}, 'FIRST_INPUT_DELAY_MS': {'percentile': 234, 'distributions': [{'min': 0, 'max': 100, 'proportion': 0.8906474820143885}, {'min': 100, 'max': 300, 'proportion': 0.09640287769784173}, {'min': 300, 'proportion': 0.012949640287769782}], 'category': 'AVERAGE'}}, 'overall_category': 'AVERAGE', 'initial_url': 'https://www.deepcrawl.com/knowledge/hangout-library/'}, 'lighthouseResult': {'requestedUrl': 'https://www.deepcrawl.com/knowledge/hangout-library/', 'finalUrl': 'https://www.deepcrawl.com/knowledge/hangout-library/', 'lighthouseVersion': '5.6.0', 'userAgent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/79.0.3945.120 Safari/537.36', 'fetchTime': '2020-03-01T17:04:05.194Z', 'environment': {'networkUserAgent': 'Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3694.0 Mobile Safari/537.36 Chrome-Lighthouse', 'hostUserAgent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/79.0.3945.120 Safari/537.36', 'benchmarkIndex': 659}, 'runWarnings': [], 'configSettings': {'emulatedFormFactor': 'mobile', 'locale': 'en-US', 'onlyCategories': ['performance'], 'channel': 'lr'}, 'audits': {'user-timings': {'id': 'user-timings', 'title': 'User Timing marks and measures', 'description': "Consider instrumenting your app with the User Timing API to measure your app's real-world performance during key user experiences. [Learn more](https://web.dev/user-timings).", 'score': None, 'scoreDisplayMode': 'notApplicable', 'details': {'headings': [], 'items': [], 'type': 'table'}}, 'first-meaningful-paint': {'id': 'first-meaningful-paint', 'title': 'First Meaningful Paint', 'description': 'First Meaningful Paint measures when the primary content of a page is visible. [Learn more](https://web.dev/first-meaningful-paint).', 'score': 0.58, 'scoreDisplayMode': 'numeric', 'displayValue': '3.7\xa0s', 'numericValue': 3675}, 'resource-summary': {'id': 'resource-summary', 'title': 'Keep request counts low and transfer sizes small', 'description': 'To set budgets for the quantity and size of page resources, add a budget.json file. [Learn more](https://developers.google.com/web/tools/lighthouse/audits/budgets).', 'score': None, 'scoreDisplayMode': 'informative', 'displayValue': '81 requests • 1,980 KB', 'details': {'headings': [{'key': 'label', 'itemType': 'text', 'text': 'Resource Type'}, {'text': 'Requests', 'key': 'requestCount', 'itemType': 'numeric'}, {'text': 'Transfer Size', 'key': 'size', 'itemType': 'bytes'}], 'items': [{'label': 'Total', 'size': 2027475, 'requestCount': 81, 'resourceType': 'total'}, {'label': 'Image', 'size': 888410, 'requestCount': 20, 'resourceType': 'image'}, {'size': 782833, 'requestCount': 33, 'resourceType': 'script', 'label': 'Script'}, {'resourceType': ...
# {'captchaResult': 'CAPTCHA_NOT_NEEDED', 'kind': 'pagespeedonline#result', 'id': 'https://www.deepcrawl.com/knowledge/getting-started/', 'loadingExperience': {'id': 'https://www.deepcrawl.com', 'metrics': {'FIRST_CONTENTFUL_PAINT_MS': {'percentile': 2792, 'distributions': [{'min': 0, 'max': 1000, 'proportion': 0.23867069486404832}, {'min': 1000, 'max': 3000, 'proportion': 0.5400302114803626}, {'min': 3000, 'proportion': 0.22129909365558914}], 'category': 'AVERAGE'}, 'FIRST_INPUT_DELAY_MS': {'percentile': 234, 'distributions': [{'min': 0, 'max': 100, 'proportion': 0.8906474820143885}, {'min': 100, 'max': 300, 'proportion': 0.09640287769784173}, {'min': 300, 'proportion': 0.012949640287769782}], 'category': 'AVERAGE'}}, 'overall_category': 'AVERAGE', 'initial_url': 'https://www.deepcrawl.com/knowledge/getting-started/'}, 'originLoadingExperience': {'id': 'https://www.deepcrawl.com', 'metrics': {'FIRST_CONTENTFUL_PAINT_MS': {'percentile': 2792, 'distributions': [{'min': 0, 'max': 1000, 'proportion': 0.23867069486404832}, {'min': 1000, 'max': 3000, 'proportion': 0.5400302114803626}, {'min': 3000, 'proportion': 0.22129909365558914}], 'category': 'AVERAGE'}, 'FIRST_INPUT_DELAY_MS': {'percentile': 234, 'distributions': [{'min': 0, 'max': 100, 'proportion': 0.8906474820143885}, {'min': 100, 'max': 300, 'proportion': 0.09640287769784173}, {'min': 300, 'proportion': 0.012949640287769782}], 'category': 'AVERAGE'}}, 'overall_category': 'AVERAGE', 'initial_url': 'https://www.deepcrawl.com/knowledge/getting-started/'}, 'lighthouseResult': {'requestedUrl': 'https://www.deepcrawl.com/knowledge/getting-started/', 'finalUrl': 'https://www.deepcrawl.com/knowledge/getting-started/', 'lighthouseVersion': '5.6.0', 'userAgent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/79.0.3945.120 Safari/537.36', 'fetchTime': '2020-03-01T17:04:45.244Z', 'environment': {'networkUserAgent': 'Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3694.0 Mobile Safari/537.36 Chrome-Lighthouse', 'hostUserAgent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/79.0.3945.120 Safari/537.36', 'benchmarkIndex': 606}, 'runWarnings': [], 'configSettings': {'emulatedFormFactor': 'mobile', 'locale': 'en-US', 'onlyCategories': ['performance'], 'channel': 'lr'}, 'audits': {'dom-size': {'id': 'dom-size', 'title': 'Avoids an excessive DOM size', 'description': 'A large DOM will increase memory usage, cause longer [style calculations](https://developers.google.com/web/fundamentals/performance/rendering/reduce-the-scope-and-complexity-of-style-calculations), and produce costly [layout reflows](https://developers.google.com/speed/articles/reflow). [Learn more](https://web.dev/dom-size).', 'score': 1, 'scoreDisplayMode': 'numeric', 'displayValue': '390 elements', 'details': {'headings': [{'key': 'statistic', 'itemType': 'text', 'text': 'Statistic'}, {'key': 'element', 'itemType': 'code', 'text': 'Element'}, {'itemType': 'numeric', 'key': 'value', 'text': 'Value'}], 'items': [{'value': '390', 'statistic': 'Total DOM Elements'}, {'value': '13', 'statistic': 'Maximum DOM Depth', 'element': {'value': '<iframe src="https://www.google.com/recaptcha/api2/anchor?ar=1&amp;k=6LfVRrAUAAAAAGLelMzYgBkLQQFpiXbwisanb27Q&amp;co=aHR0cHM6Ly93d3cuZGVlcGNyYXdsLmNvbTo0NDM.&amp;hl=en&amp;v=61bII03-TtCmSUR7dw9MJF9q&amp;theme=light&amp;size=normal&amp;cb=na7rj3sep0f1" width="304" height="78" role="presentation" name="a-cwugfo7abrsj" frameborder="0" scrolling="no" sandbox="allow-forms allow-popups allow-same-origin allow-scripts allow-top-navigation allow-modals allow-popups-to-escape-sandbox">', 'type': 'code'}}, {'value': '56', 'statistic': 'Maximum Child Elements', 'element': {'type': 'code', 'value': '<article class="content">'}}], 'type': 'table'}, 'numericValue': 390}, 'uses-rel-preload': {'id': 'uses-rel-preload', 'title': 'Preload key requests', 'description': 'Conside ...
# {'captchaResult': 'CAPTCHA_NOT_NEEDED', 'kind': 'pagespeedonline#result', 'id': 'https://www.deepcrawl.com/why-enterprise-brands/', 'loadingExperience': {'id': 'https://www.deepcrawl.com', 'metrics': {'FIRST_INPUT_DELAY_MS': {'percentile': 234, 'distributions': [{'min': 0, 'max': 100, 'proportion': 0.8906474820143885}, {'min': 100, 'max': 300, 'proportion': 0.09640287769784173}, {'min': 300, 'proportion': 0.012949640287769782}], 'category': 'AVERAGE'}, 'FIRST_CONTENTFUL_PAINT_MS': {'percentile': 2792, 'distributions': [{'min': 0, 'max': 1000, 'proportion': 0.23867069486404832}, {'min': 1000, 'max': 3000, 'proportion': 0.5400302114803626}, {'min': 3000, 'proportion': 0.22129909365558914}], 'category': 'AVERAGE'}}, 'overall_category': 'AVERAGE', 'initial_url': 'https://www.deepcrawl.com/why-enterprise-brands/'}, 'originLoadingExperience': {'id': 'https://www.deepcrawl.com', 'metrics': {'FIRST_INPUT_DELAY_MS': {'percentile': 234, 'distributions': [{'min': 0, 'max': 100, 'proportion': 0.8906474820143885}, {'min': 100, 'max': 300, 'proportion': 0.09640287769784173}, {'min': 300, 'proportion': 0.012949640287769782}], 'category': 'AVERAGE'}, 'FIRST_CONTENTFUL_PAINT_MS': {'percentile': 2792, 'distributions': [{'min': 0, 'max': 1000, 'proportion': 0.23867069486404832}, {'min': 1000, 'max': 3000, 'proportion': 0.5400302114803626}, {'min': 3000, 'proportion': 0.22129909365558914}], 'category': 'AVERAGE'}}, 'overall_category': 'AVERAGE', 'initial_url': 'https://www.deepcrawl.com/why-enterprise-brands/'}, 'lighthouseResult': {'requestedUrl': 'https://www.deepcrawl.com/why-enterprise-brands/', 'finalUrl': 'https://www.deepcrawl.com/why-enterprise-brands/', 'lighthouseVersion': '5.6.0', 'userAgent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/79.0.3945.120 Safari/537.36', 'fetchTime': '2020-03-01T17:05:26.481Z', 'environment': {'networkUserAgent': 'Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3694.0 Mobile Safari/537.36 Chrome-Lighthouse', 'hostUserAgent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/79.0.3945.120 Safari/537.36', 'benchmarkIndex': 825}, 'runWarnings': [], 'configSettings': {'emulatedFormFactor': 'mobile', 'locale': 'en-US', 'onlyCategories': ['performance'], 'channel': 'lr'}, 'audits': {'uses-rel-preconnect': {'id': 'uses-rel-preconnect', 'title': 'Preconnect to required origins', 'description': 'Consider adding `preconnect` or `dns-prefetch` resource hints to establish early connections to important third-party origins. [Learn more](https://web.dev/uses-rel-preconnect).', 'score': 1, 'scoreDisplayMode': 'numeric', 'details': {'overallSavingsMs': 0, 'headings': [], 'items': [], 'type': 'opportunity'}, 'warnings': [], 'numericValue': 0}, 'unminified-css': {'id': 'unminified-css', 'title': 'Minify CSS', 'description': 'Minifying CSS files can reduce network payload sizes. [Learn more](https://web.dev/unminified-css).', 'score': 1, 'scoreDisplayMode': 'numeric', 'details': {'headings': [], 'type': 'opportunity', 'items': [], 'overallSavingsBytes': 0, 'overallSavingsMs': 0}, 'numericValue': 0}, 'bootup-time': {'id': 'bootup-time', 'title': 'JavaScript execution time', 'description': 'Consider reducing the time spent parsing, compiling, and executing JS. You may find delivering smaller JS payloads helps with this. [Learn more](https://web.dev/bootup-time).', 'score': 0.92, 'scoreDisplayMode': 'numeric', 'displayValue': '1.2\xa0s', 'details': {'summary': {'wastedMs': 1175.6560000000002}, 'headings': [{'itemType': 'url', 'key': 'url', 'text': 'URL'}, {'key': 'total', 'itemType': 'ms', 'text': 'Total CPU Time', 'granularity': 1}, {'granularity': 1, 'key': 'scripting', 'itemType': 'ms', 'text': 'Script Evaluation'}, {'key': 'scriptParseCompile', 'itemType': 'ms', 'text': 'Script Parse', 'granularity': 1}], 'type': 'table', 'items': [{'scriptParseCompile': 6.6160000000000005, 'url': 'Other ...
# {'captchaResult': 'CAPTCHA_NOT_NEEDED', 'kind': 'pagespeedonline#result', 'id': 'https://www.deepcrawl.com/careers/', 'loadingExperience': {'id': 'https://www.deepcrawl.com', 'metrics': {'FIRST_CONTENTFUL_PAINT_MS': {'percentile': 2792, 'distributions': [{'min': 0, 'max': 1000, 'proportion': 0.23867069486404832}, {'min': 1000, 'max': 3000, 'proportion': 0.5400302114803626}, {'min': 3000, 'proportion': 0.22129909365558914}], 'category': 'AVERAGE'}, 'FIRST_INPUT_DELAY_MS': {'percentile': 234, 'distributions': [{'min': 0, 'max': 100, 'proportion': 0.8906474820143885}, {'min': 100, 'max': 300, 'proportion': 0.09640287769784173}, {'min': 300, 'proportion': 0.012949640287769782}], 'category': 'AVERAGE'}}, 'overall_category': 'AVERAGE', 'initial_url': 'https://www.deepcrawl.com/careers/'}, 'originLoadingExperience': {'id': 'https://www.deepcrawl.com', 'metrics': {'FIRST_CONTENTFUL_PAINT_MS': {'percentile': 2792, 'distributions': [{'min': 0, 'max': 1000, 'proportion': 0.23867069486404832}, {'min': 1000, 'max': 3000, 'proportion': 0.5400302114803626}, {'min': 3000, 'proportion': 0.22129909365558914}], 'category': 'AVERAGE'}, 'FIRST_INPUT_DELAY_MS': {'percentile': 234, 'distributions': [{'min': 0, 'max': 100, 'proportion': 0.8906474820143885}, {'min': 100, 'max': 300, 'proportion': 0.09640287769784173}, {'min': 300, 'proportion': 0.012949640287769782}], 'category': 'AVERAGE'}}, 'overall_category': 'AVERAGE', 'initial_url': 'https://www.deepcrawl.com/careers/'}, 'lighthouseResult': {'requestedUrl': 'https://www.deepcrawl.com/careers/', 'finalUrl': 'https://www.deepcrawl.com/careers/', 'lighthouseVersion': '5.6.0', 'userAgent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/79.0.3945.120 Safari/537.36', 'fetchTime': '2020-03-01T17:06:05.322Z', 'environment': {'networkUserAgent': 'Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3694.0 Mobile Safari/537.36 Chrome-Lighthouse', 'hostUserAgent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/79.0.3945.120 Safari/537.36', 'benchmarkIndex': 732}, 'runWarnings': [], 'configSettings': {'emulatedFormFactor': 'mobile', 'locale': 'en-US', 'onlyCategories': ['performance'], 'channel': 'lr'}, 'audits': {'speed-index': {'id': 'speed-index', 'title': 'Speed Index', 'description': 'Speed Index shows how quickly the contents of a page are visibly populated. [Learn more](https://web.dev/speed-index).', 'score': 0.91, 'scoreDisplayMode': 'numeric', 'displayValue': '3.3\xa0s', 'numericValue': 3267.4784196491246}, 'unused-css-rules': {'id': 'unused-css-rules', 'title': 'Remove unused CSS', 'description': 'Remove dead rules from stylesheets and defer the loading of CSS not used for above-the-fold content to reduce unnecessary bytes consumed by network activity. [Learn more](https://web.dev/unused-css-rules).', 'score': 0.75, 'scoreDisplayMode': 'numeric', 'displayValue': 'Potential savings of 42\xa0KB', 'details': {'headings': [{'label': 'URL', 'key': 'url', 'valueType': 'url'}, {'key': 'totalBytes', 'valueType': 'bytes', 'label': 'Size'}, {'key': 'wastedBytes', 'valueType': 'bytes', 'label': 'Potential Savings'}], 'type': 'opportunity', 'items': [{'wastedPercent': 93.70565732486223, 'url': 'https://www.deepcrawl.com/wp-content/themes/deepcrawl/build/styles.min.css?ver=5.2.2.1', 'totalBytes': 31006, 'wastedBytes': 29054}, {'wastedPercent': 100, 'url': 'https://kit-free.fontawesome.com/releases/latest/css/free.min.css', 'totalBytes': 13752, 'wastedBytes': 13752}], 'overallSavingsBytes': 42806, 'overallSavingsMs': 300}, 'numericValue': 300}, 'first-cpu-idle': {'id': 'first-cpu-idle', 'title': 'First CPU Idle', 'description': "First CPU Idle marks the first time at which the page's main thread is quiet enough to handle input.  [Learn more](https://web.dev/first-cpu-idle).", 'score': 0.43, 'scoreDisplayMode': 'numeric', 'displayValue': '7.1\xa0s', 'numericValue': 7077}, 'total- ...
# {'captchaResult': 'CAPTCHA_NOT_NEEDED', 'kind': 'pagespeedonline#result', 'id': 'https://www.deepcrawl.com/free-trial/', 'loadingExperience': {'id': 'https://www.deepcrawl.com', 'metrics': {'FIRST_CONTENTFUL_PAINT_MS': {'percentile': 2792, 'distributions': [{'min': 0, 'max': 1000, 'proportion': 0.23867069486404832}, {'min': 1000, 'max': 3000, 'proportion': 0.5400302114803626}, {'min': 3000, 'proportion': 0.22129909365558914}], 'category': 'AVERAGE'}, 'FIRST_INPUT_DELAY_MS': {'percentile': 234, 'distributions': [{'min': 0, 'max': 100, 'proportion': 0.8906474820143885}, {'min': 100, 'max': 300, 'proportion': 0.09640287769784173}, {'min': 300, 'proportion': 0.012949640287769782}], 'category': 'AVERAGE'}}, 'overall_category': 'AVERAGE', 'initial_url': 'https://www.deepcrawl.com/free-trial/'}, 'originLoadingExperience': {'id': 'https://www.deepcrawl.com', 'metrics': {'FIRST_CONTENTFUL_PAINT_MS': {'percentile': 2792, 'distributions': [{'min': 0, 'max': 1000, 'proportion': 0.23867069486404832}, {'min': 1000, 'max': 3000, 'proportion': 0.5400302114803626}, {'min': 3000, 'proportion': 0.22129909365558914}], 'category': 'AVERAGE'}, 'FIRST_INPUT_DELAY_MS': {'percentile': 234, 'distributions': [{'min': 0, 'max': 100, 'proportion': 0.8906474820143885}, {'min': 100, 'max': 300, 'proportion': 0.09640287769784173}, {'min': 300, 'proportion': 0.012949640287769782}], 'category': 'AVERAGE'}}, 'overall_category': 'AVERAGE', 'initial_url': 'https://www.deepcrawl.com/free-trial/'}, 'lighthouseResult': {'requestedUrl': 'https://www.deepcrawl.com/free-trial/', 'finalUrl': 'https://www.deepcrawl.com/free-trial/', 'lighthouseVersion': '5.6.0', 'userAgent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/79.0.3945.120 Safari/537.36', 'fetchTime': '2020-03-01T17:06:44.965Z', 'environment': {'networkUserAgent': 'Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3694.0 Mobile Safari/537.36 Chrome-Lighthouse', 'hostUserAgent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/79.0.3945.120 Safari/537.36', 'benchmarkIndex': 914}, 'runWarnings': [], 'configSettings': {'emulatedFormFactor': 'mobile', 'locale': 'en-US', 'onlyCategories': ['performance'], 'channel': 'lr'}, 'audits': {'time-to-first-byte': {'id': 'time-to-first-byte', 'title': 'Server response times are low (TTFB)', 'description': 'Time To First Byte identifies the time at which your server sends a response. [Learn more](https://web.dev/time-to-first-byte).', 'score': 1, 'scoreDisplayMode': 'binary', 'displayValue': 'Root document took 550\xa0ms', 'details': {'headings': [], 'items': [], 'type': 'opportunity', 'overallSavingsMs': -48.307000000000016}, 'numericValue': 551.693}, 'render-blocking-resources': {'id': 'render-blocking-resources', 'title': 'Eliminate render-blocking resources', 'description': 'Resources are blocking the first paint of your page. Consider delivering critical JS/CSS inline and deferring all non-critical JS/styles. [Learn more](https://web.dev/render-blocking-resources).', 'score': 0.47, 'scoreDisplayMode': 'numeric', 'displayValue': 'Potential savings of 1,020\xa0ms', 'details': {'headings': [{'valueType': 'url', 'label': 'URL', 'key': 'url'}, {'valueType': 'bytes', 'label': 'Size', 'key': 'totalBytes'}, {'key': 'wastedMs', 'valueType': 'timespanMs', 'label': 'Potential Savings'}], 'type': 'opportunity', 'items': [{'wastedMs': 180, 'url': 'https://www.deepcrawl.com/wp-includes/css/dist/block-library/style.min.css?ver=5.2.4', 'totalBytes': 6552}, {'wastedMs': 480, 'url': 'https://www.deepcrawl.com/wp-content/themes/deepcrawl/build/styles.min.css?ver=5.2.2.1', 'totalBytes': 31006}, {'url': 'https://www.deepcrawl.com/wp-includes/js/jquery/jquery.js?ver=1.12.4-wp', 'totalBytes': 40077, 'wastedMs': 330}, {'url': 'https://www.deepcrawl.com/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1', 'totalBytes': 4983, 'wastedMs': 180}, {'wastedMs': 7 ...
# {'captchaResult': 'CAPTCHA_NOT_NEEDED', 'kind': 'pagespeedonline#result', 'id': 'https://www.deepcrawl.com/faqs/', 'loadingExperience': {'id': 'https://www.deepcrawl.com', 'metrics': {'FIRST_CONTENTFUL_PAINT_MS': {'percentile': 2792, 'distributions': [{'min': 0, 'max': 1000, 'proportion': 0.23867069486404832}, {'min': 1000, 'max': 3000, 'proportion': 0.5400302114803626}, {'min': 3000, 'proportion': 0.22129909365558914}], 'category': 'AVERAGE'}, 'FIRST_INPUT_DELAY_MS': {'percentile': 234, 'distributions': [{'min': 0, 'max': 100, 'proportion': 0.8906474820143885}, {'min': 100, 'max': 300, 'proportion': 0.09640287769784173}, {'min': 300, 'proportion': 0.012949640287769782}], 'category': 'AVERAGE'}}, 'overall_category': 'AVERAGE', 'initial_url': 'https://www.deepcrawl.com/faqs/'}, 'originLoadingExperience': {'id': 'https://www.deepcrawl.com', 'metrics': {'FIRST_CONTENTFUL_PAINT_MS': {'percentile': 2792, 'distributions': [{'min': 0, 'max': 1000, 'proportion': 0.23867069486404832}, {'min': 1000, 'max': 3000, 'proportion': 0.5400302114803626}, {'min': 3000, 'proportion': 0.22129909365558914}], 'category': 'AVERAGE'}, 'FIRST_INPUT_DELAY_MS': {'percentile': 234, 'distributions': [{'min': 0, 'max': 100, 'proportion': 0.8906474820143885}, {'min': 100, 'max': 300, 'proportion': 0.09640287769784173}, {'min': 300, 'proportion': 0.012949640287769782}], 'category': 'AVERAGE'}}, 'overall_category': 'AVERAGE', 'initial_url': 'https://www.deepcrawl.com/faqs/'}, 'lighthouseResult': {'requestedUrl': 'https://www.deepcrawl.com/faqs/', 'finalUrl': 'https://www.deepcrawl.com/faqs/', 'lighthouseVersion': '5.6.0', 'userAgent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/79.0.3945.120 Safari/537.36', 'fetchTime': '2020-03-01T17:07:22.313Z', 'environment': {'networkUserAgent': 'Mozilla/5.0 (Linux; Android 6.0.1; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3694.0 Mobile Safari/537.36 Chrome-Lighthouse', 'hostUserAgent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/79.0.3945.120 Safari/537.36', 'benchmarkIndex': 668}, 'runWarnings': [], 'configSettings': {'emulatedFormFactor': 'mobile', 'locale': 'en-US', 'onlyCategories': ['performance'], 'channel': 'lr'}, 'audits': {'unminified-javascript': {'id': 'unminified-javascript', 'title': 'Minify JavaScript', 'description': 'Minifying JavaScript files can reduce payload sizes and script parse time. [Learn more](https://web.dev/unminified-javascript).', 'score': 1, 'scoreDisplayMode': 'numeric', 'displayValue': 'Potential savings of 2\xa0KB', 'details': {'overallSavingsMs': 0, 'headings': [{'valueType': 'url', 'label': 'URL', 'key': 'url'}, {'valueType': 'bytes', 'label': 'Size', 'key': 'totalBytes'}, {'key': 'wastedBytes', 'valueType': 'bytes', 'label': 'Potential Savings'}], 'type': 'opportunity', 'items': [{'wastedBytes': 2502, 'wastedPercent': 44.77380706465607, 'url': 'https://www.deepcrawl.com/wp-content/themes/deepcrawl/build/custom.js?ver=0.0.1', 'totalBytes': 5588}], 'overallSavingsBytes': 2502}, 'warnings': [], 'numericValue': 0}, 'redirects': {'id': 'redirects', 'title': 'Avoid multiple page redirects', 'description': 'Redirects introduce additional delays before the page can be loaded. [Learn more](https://web.dev/redirects).', 'score': 1, 'scoreDisplayMode': 'numeric', 'details': {'overallSavingsMs': 0, 'headings': [], 'items': [], 'type': 'opportunity'}, 'numericValue': 0}, 'user-timings': {'id': 'user-timings', 'title': 'User Timing marks and measures', 'description': "Consider instrumenting your app with the User Timing API to measure your app's real-world performance during key user experiences. [Learn more](https://web.dev/user-timings).", 'score': None, 'scoreDisplayMode': 'notApplicable', 'details': {'headings': [], 'type': 'table', 'items': []}}, 'first-meaningful-paint': {'id': 'first-meaningful-paint', 'title': 'First Meaningful Paint', 'description': 'First Meaningful Paint mea ...

# %% [markdown]
# Create dataframe to store responses

# %%
# Create dataframe to store field data responses
df_pagespeed_results = pd.DataFrame(
columns=['url',
         'FCP_category',
         'FCP_percentile',
         'FID_category',
         'FID_percentile',
         'Time_to_Interactive',
         'Speed_Index',
         'First_CPU_Idle',
         'First_Meaningful_Paint',
         'TTFB',
         'Total_Blocking_Time'])  

print(df_pagespeed_results)
# Out:
# Empty DataFrame
# Columns: [url, FCP_category, FCP_percentile, FID_category, FID_percentile, Time_to_Interactive, Speed_Index, First_CPU_Idle, First_Meaningful_Paint, TTFB, Total_Blocking_Time]
# Index: []

# %% [markdown]
# Iterate through the response object to pull out desired metrics

# %%
for (url, i) in zip(
    response_object.keys(),
    range(0, len(response_object))
):

        # URLs
        df_pagespeed_results.loc[i, 'url'] =\
            response_object[url]['lighthouseResult']['finalUrl']

        # First Contentful Paint 
        fcp = response_object[url]\
            ['loadingExperience']['metrics']['FIRST_CONTENTFUL_PAINT_MS']

        # First Input Delay 
        fid = response_object[url]\
            ['loadingExperience']['metrics']['FIRST_INPUT_DELAY_MS']

        # First Contentful Paint Metrics     
        df_pagespeed_results.loc[i, 'FCP_category'] = fcp['category']
        df_pagespeed_results.loc[i, 'FCP_percentile'] = fcp['percentile']

        # First Input Delay Metrics     
        df_pagespeed_results.loc[i, 'FID_category'] = fid['category']
        df_pagespeed_results.loc[i, 'FID_percentile'] = fid['percentile']

        # Time to Interactive  
        df_pagespeed_results.loc[i, 'Time_to_Interactive'] =\
        response_object[url]['lighthouseResult']['audits']['interactive']['displayValue']

        # Speed Index
        df_pagespeed_results.loc[i, 'Speed_Index'] =\
        response_object[url]['lighthouseResult']['audits']['speed-index']['displayValue']

        # First CPU Idle
        df_pagespeed_results.loc[i, 'First_CPU_Idle'] =\
        response_object[url]['lighthouseResult']['audits']['first-cpu-idle']['displayValue']

        # First Meaningful Paint    
        df_pagespeed_results.loc[i, 'First_Meaningful_Paint'] =\
        response_object[url]['lighthouseResult']['audits']['first-meaningful-paint']['displayValue']

         # Time to First Byte    
        df_pagespeed_results.loc[i, 'TTFB'] =\
        response_object[url]['lighthouseResult']['audits']['time-to-first-byte']['displayValue']

        # Total Blocking Time   
        df_pagespeed_results.loc[i, 'Total_Blocking_Time'] =\
        response_object[url]['lighthouseResult']['audits']['total-blocking-time']['displayValue']

        #print(df_pagespeed_results)

# %% [markdown]
# Create a summary dataframe of the results collected

# %%
summary = df_pagespeed_results

df_pagespeed_results.head()
# Out:
#                                                  url  ... Total_Blocking_Time
# 0                         https://www.deepcrawl.com/  ...            1,100 ms
# 1                 https://www.deepcrawl.com/pricing/  ...            1,530 ms
# 2                    https://www.deepcrawl.com/blog/  ...              850 ms
# 3  https://www.deepcrawl.com/knowledge/hangout-li...  ...            1,060 ms
# 4  https://www.deepcrawl.com/knowledge/getting-st...  ...            1,060 ms
#
# [5 rows x 11 columns]

# %% [markdown]
# Download the csv file

# %%
#Download csv file 
summary.to_csv('pagespeed_results.csv')
files.download('pagespeed_results.csv')
